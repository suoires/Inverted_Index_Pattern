# %%
# Install dependencies via unix ternimal:
#xcode-select --install
#brew cask install java
#brew install scala
#brew install apache-spark
#pip install findspark 
#pip install pyspark

# %%
# Import Libraries:
#import findspark (not needed since spark PATH has been defined)
#findspark.init('/usr/hdp/2.6.3.0-235/spark2')
import pyspark
import matplotlib.pyplot as plt
from functools import reduce
from collections import Counter
from nltk.corpus import stopwords

# %% [markdown]
# # Inverted Indexing Problem

# %% [markdown]
# ### Introduction:
#
# The inverted indexing project is Thien Nghiem's submission for MSDS Data Engineering class of Spring 2018.
#
# This Jupyter Notebook contains the solution for the inverted index summarization of the Stack Overflow dataset. The objective of this project is to index large datasets on keywords for conveniency in tracing terms back to records that contain specific values. This process is similar to how indexes were built by search engines to improve search performance.
#
# In the context of big data, I will use Apache Spark to perform the MapReduce component of this project. Next, I will use Spark SQL and dataframe for querying and displaying the indexing results from the MapReduce job. This project illustrates the integration of various Data Engineering components such as Python, HDFS, Spark, SQL, MapReduce, to solve the problem of inverted indexing on large datasets.
#
# ### Motivation:
#
# It is often convenient to index large data sets on keywords, so that searches can trace terms back to records that contain specific values. While building an inverted index does require extra processing up front, taking the time to do so can greatly reduce the amount of time it takes to find something.
#
# Search engines build indexes to improve search performance. Imagine entering a keyword and letting the engine crawl the Internet and build a list of pages to return to you. Such a query would take an extremely long amount of time to complete. By building an inverted index, the search engine knows all the web pages related to a keyword ahead of time and these results are simply displayed to the user. These indexes are often ingested into a database for fast query responses. Building an inverted index is a fairly straightforward application of MapReduce because the framework handles a majority of the work.

# %% [markdown]
# #### Data source:
# The data has been retrieved from: https://data.stackexchange.com/stackoverflow/
#
# ***SQL query:***
# SELECT Id, Tags FROM Posts WHERE Tags is not null;

# %%
# Import query results to spark:
sc = pyspark.SparkContext(appName="Reverse Indexing") # sc = spark context
text_file = sc.textFile("QueryResults.csv")

# %% [markdown]
# ### Map:

# %%
# Step 1- Preprocessing: Remove the commas and characters
step1 = text_file.map(lambda x: x.replace(',','').replace('<', ' ').replace('>',' ').split())
step1.take(5)
# Out:
# [['1596943', 'html', 'asp.net', 'footer'],
#  ['1596945', 'macos', 'gcc', 'otool'],
#  ['1596947', 'android'],
#  ['1596950', 'c#', '.net', 'wmi', 'device-manager'],
#  ['1596951', 'java', 'database', 'hibernate', 'orm', 'jpa']]

# %%
# Step 2: Invert Indexing using Tags instead of Userids
step2 = step1.flatMap(lambda wlist: [[wlist[i],wlist[0]] for i in range(1,len(wlist))])
step2.take(5)
# Out:
# [['html', '1596943'],
#  ['asp.net', '1596943'],
#  ['footer', '1596943'],
#  ['macos', '1596945'],
#  ['gcc', '1596945']]

# %% [markdown]
# ### Reduce:

# %% [markdown]
# Reduce the list by key. In this case, we reduce by adding up all the values that shared the same key (tag)

# %%
# create a tuple contain Tag and Ids that associated with the tag
step3 = step2.reduceByKey(lambda total, count: total + ',' + count).map(lambda x: (x[0],x[1].split(",")))
step3.take(1)
# Out:
# [('html',
#   ['1596943',
#    '33668105',
#    '33681754',
#    '33681755',
#    '41673571',
#    '42401334',
#    '19020553',
#    '33324159',
#    '32689570',
#    '24671562',
#    '16359272',
#    '8382136',
#    '26420415',
#    '26420430',
#    '32946083',
#    '32946104',
#    '24672075',
#    '40732817',
#    '40732864',
#    '40732888',
#    '40732906',
#    '40732072',
#    '41429386',
#    '24671028',
#    '4923',
#    '4973',
#    '40733081',
#    '40733153',
#    '16360215',
#    '33828277',
#    '26062623',
#    '39438711',
#    '24674050',
#    '24674064',
#    '40733828',
#    '40733840',
#    '40733868',
#    '32691429',
#    '32691517',
#    '40732437',
#    '40732448',
#    '24671968',
#    '24671971',
#    '40734234',
#    '32692381',
#    '32692422',
#    '32691050',
#    '32691120',
#    '24673178',
#    '24672104',
#    '24672112',
#    '24672122',
#    '24672201',
#    '4880',
#    '24675355',
#    '8236666',
#    '32691857',
#    '32691862',
#    '24673953',
#    '24674005',
#    '24674020',
#    '24674021',
#    '16905095',
#    '34472917',
#    '33165353',
#    '33165355',
#    '16361606',
#    '24674687',
#    '24674717',
#    '24674727',
#    '24674728',
#    '32692456',
#    '8237550',
#    '8237568',
#    '40734855',
#    '40734861',
#    '8240818',
#    '8240823',
#    '32694143',
#    '12794',
#    '24676743',
#    '8238675',
#    '8238678',
#    '8238683',
#    '40736503',
#    '40736529',
#    '40735340',
#    '40735344',
#    '10366',
#    '24675885',
#    '24675925',
#    '8240887',
#    '40737721',
#    '8237708',
#    '8238110',
#    '8238114',
#    '8238117',
#    '24675280',
#    '1563062',
#    '40737169',
#    '32694767',
#    '32694788',
#    '24678448',
#    '24678468',
#    '9508599',
#    '9508749',
#    '16362471',
#    '33641105',
#    '33641113',
#    '16363210',
#    '41607792',
#    '41607828',
#    '17541432',
#    '17541540',
#    '33641410',
#    '41607897',
#    '41607922',
#    '33641178',
#    '33641203',
#    '33641208',
#    '25783261',
#    '9508467',
#    '9508489',
#    '9508496',
#    '9508325',
#    '9508367',
#    '9508370',
#    '9508376',
#    '9508899',
#    '1563877',
#    '1563924',
#    '1564070',
#    '8240238',
#    '16364516',
#    '25783356',
#    '25783363',
#    '33641521',
#    '33641623',
#    '9509031',
#    '17541570',
#    '17541614',
#    '17541699',
#    '1565052',
#    '1565229',
#    '41608035',
#    '41608068',
#    '25783755',
#    '25783803',
#    '41608430',
#    '41608509',
#    '33641671',
#    '33641721',
#    '41608259',
#    '41608332',
#    '41608615',
#    '41608646',
#    '17542108',
#    '25783454',
#    '25783458',
#    '25783476',
#    '9509052',
#    '25783580',
#    '25783602',
#    '25783615',
#    '1565022',
#    '1566141',
#    '1566163',
#    '1565971',
#    '25783870',
#    '1565822',
#    '1565896',
#    '1565928',
#    '9509075',
#    '41608525',
#    '41608540',
#    '17541962',
#    '1565624',
#    '17542253',
#    '17542283',
#    '17542322',
#    '9509300',
#    '1567373',
#    '9509593',
#    '33641903',
#    '33641916',
#    '33641925',
#    '33641930',
#    '33641988',
#    '41608209',
#    '41608218',
#    '9508771',
#    '1566859',
#    '1567534',
#    '33642131',
#    '33642148',
#    '33642193',
#    '33642201',
#    '33642241',
#    '33642254',
#    '33642013',
#    '33642098',
#    '33642114',
#    '1567064',
#    '9509651',
#    '17542502',
#    '17542611',
#    '1567419',
#    '1567420',
#    '1566379',
#    '41608696',
#    '1567592',
#    '1567644',
#    '1567752',
#    '1567836',
#    '9509742',
#    '9509758',
#    '1566665',
#    '25783959',
#    '25783986',
#    '25784020',
#    '25784021',
#    '25784056',
#    '9509479',
#    '41608853',
#    '41608910',
#    '25784180',
#    '25784185',
#    '25784207',
#    '25784214',
#    '1567207',
#    '1568607',
#    '1568658',
#    '33642352',
#    '1568087',
#    '1568144',
#    '33642387',
#    '33642406',
#    '33642448',
#    '33642494',
#    '33642496',
#    '1568487',
#    '1569457',
#    '25784609',
#    '25784644',
#    '9509989',
#    '17542795',
#    '1569283',
#    '1569313',
#    '17542937',
#    '17543077',
#    '25784729',
#    '25784731',
#    '25784761',
#    '17543150',
#    '25784944',
#    '1569567',
#    '33642766',
#    '9510227',
#    '25785073',
#    '25785075',
#    '25785090',
#    '25785113',
#    '1569889',
#    '1569898',
#    '1569917',
#    '1568806',
#    '1571125',
#    '1571146',
#    '25784780',
#    '25784826',
#    '25784829',
#    '25784830',
#    '9510007',
#    '9510122',
#    '1571707',
#    '9510359',
#    '1570086',
#    '1570104',
#    '1570206',
#    '1571395',
#    '1571434',
#    '1571455',
#    '1571517',
#    '1571648',
#    '41609065',
#    '1569245',
#    '1570418',
#    '1570540',
#    '1570808',
#    '1571765',
#    '1571806',
#    '1571830',
#    '1572046',
#    '17543319',
#    '25785142',
#    '1573484',
#    '1572740',
#    '1573010',
#    '25785180',
#    '25785195',
#    '25785260',
#    '9510446',
#    '9510482',
#    '9510525',
#    '1573946',
#    '25784963',
#    '25785005',
#    '9510710',
#    '41609242',
#    '41609267',
#    '41609309',
#    '1572410',
#    '9510807',
#    '9510827',
#    '9510838',
#    '1570905',
#    '1570966',
#    '1573961',
#    '41609114',
#    '41609121',
#    '1573582',
#    '17543233',
#    '17543258',
#    '17543971',
#    '1574866',
#    '33642916',
#    '33642955',
#    '25785519',
#    '25785532',
#    '25785588',
#    '25785610',
#    '41609444',
#    '25785480',
#    '25785505',
#    '17543617',
#    '1574114',
#    '9510623',
#    '9510637',
#    '9510650',
#    '1575141',
#    '33642980',
#    '33642984',
#    '33642990',
#    '33643018',
#    '1574936',
#    '1574961',
#    '17543744',
#    '17543763',
#    '17543815',
#    '1575333',
#    '1575426',
#    '9511159',
#    '17543588',
#    '1574385',
#    '33642807',
#    '33642812',
#    '17544040',
#    '1575444',
#    '41609481',
#    '9511023',
#    '1575274',
#    '1576231',
#    '25785955',
#    '25785985',
#    '1574679',
#    '41609330',
#    '25785890',
#    '25785927',
#    '33643215',
#    '1575617',
#    '1575866',
#    '1575558',
#    '33643124',
#    '33643169',
#    '1576604',
#    '1576675',
#    '1576694',
#    '1576719',
#    '25786078',
#    '1576431',
#    '1576459',
#    '17544294',
#    '17544359',
#    '17544384',
#    '33643268',
#    '17544123',
#    '17544144',
#    '17544185',
#    '17544190',
#    '17544264',
#    '17544292',
#    '9511328',
#    '33643350',
#    '33643422',
#    '33643435',
#    '9511503',
#    '9511526',
#    '33643559',
#    '33643580',
#    '33643592',
#    '33643618',
#    '33643639',
#    '17544440',
#    '25786376',
#    '25786383',
#    '25786387',
#    '25786406',
#    '1577651',
#    '1577678',
#    '1577680',
#    '1577757',
#    '17544625',
#    '17544635',
#    '1577368',
#    '1578159',
#    '1578186',
#    '1578386',
#    '41609850',
#    '41609907',
#    '41609926',
#    '9511396',
#    '1577814',
#    '1577905',
#    '41609792',
#    '25786121',
#    '25786126',
#    '25786141',
#    '25786169',
#    '9512244',
#    '41610134',
#    '33643778',
#    '9511987',
#    '41610056',
#    '1577987',
#    '1578091',
#    '1577598',
#    '41610222',
#    '41610237',
#    '41610299',
#    '41610301',
#    '41610437',
#    '41610466',
#    '41610487',
#    '33644219',
#    '33644226',
#    '9512709',
#    '9512808',
#    '33644014',
#    '1578991',
#    '9513072',
#    '9512313',
#    '9512330',
#    '1579133',
#    '1579757',
#    '1579795',
#    '1579865',
#    '17544679',
#    '17544692',
#    '33644082',
#    '33644099',
#    '33644136',
#    '33644153',
#    '33644155',
#    '33644174',
#    '1579454',
#    '1579526',
#    '41610623',
#    '33644325',
#    '33644332',
#    '33644363',
#    '33644364',
#    '33644402',
#    '9513272',
#    '41610814',
#    '41610865',
#    '33644440',
#    '33644449',
#    '33644489',
#    '33644509',
#    '33644518',
#    '33644532',
#    '41610716',
#    '41610740',
#    '1580136',
#    '1580388',
#    '1580456',
#    '9513305',
#    '9513336',
#    '9512922',
#    '9512923',
#    '9512965',
#    '9512999',
#    '1580630',
#    '1580922',
#    '25786494',
#    '1580987',
#    '1581152',
#    '9513379',
#    '9513419',
#    '33644718',
#    '33644767',
#    '33644804',
#    '25786553',
#    '25786577',
#    '1581489',
#    '1581551',
#    '9513567',
#    '25786724',
#    '25786742',
#    '41611027',
#    '1580696',
#    '1580701',
#    '1580793',
#    '1580809',
#    '33644918',
#    '33644944',
#    '25786625',
#    '1582717',
#    '1582219',
#    '1582361',
#    '1582463',
#    '1581398',
#    '1581806',
#    '17545104',
#    '1581765',
#    '33644861',
#    '33645074',
#    '33645145',
#    '1583269',
#    '9513931',
#    '25786981',
#    '25786987',
#    '25787079',
#    '25786916',
#    '25786931',
#    '1582487',
#    '1582517',
#    '1582528',
#    '41611348',
#    '1583373',
#    '1583390',
#    '1584322',
#    '17545642',
#    '1584850',
#    '1585000',
#    '1584021',
#    '25787399',
#    '25787404',
#    '25787131',
#    '25787166',
#    '1585480',
#    '25787316',
#    '33645329',
#    '33645345',
#    '1583548',
#    '1583628',
#    '9514089',
#    '9514159',
#    '17545662',
#    '17545667',
#    '1584667',
#    '1584720',
#    '25787469',
#    '33645496',
#    '33645509',
#    '33645525',
#    '1587667',
#    '1587686',
#    '33645381',
#    '33645401',
#    '33645418',
#    '17545430',
#    '41611250',
#    '41611291',
#    '1585110',
#    '1585217',
#    '1585220',
#    '1585347',
#    '1583896',
#    '1583901',
#    '1586979',
#    '1587122',
#    '1585668',
#    '1585675',
#    '1585723',
#    '1586056',
#    '1586360',
#    '1587797',
#    '1587798',
#    '1587890',
#    '1587927',
#    '1588521',
#    '1588790',
#    '1588876',
#    '1588888',
#    '1586734',
#    '33645667',
#    '33645685',
#    '9514216',
#    '41611307',
#    '1589241',
#    '1589361',
#    '1589472',
#    '1587637',
#    '1587652',
#    '1590568',
#    '1590631',
#    '1590840',
#    '1588068',
#    '1588162',
#    '1588271',
#    '1588302',
#    '1588341',
#    '1590936',
#    '1590965',
#    '41611460',
#    '41611486',
#    '41611540',
#    '33645583',
#    '1589065',
#    '1591308',
#    '1591350',
#    '17545810',
#    '33645700',
#    '33645717',
#    '33645731',
#    '41611590',
#    '41611599',
#    '41611613',
#    '41611618',
#    '25787570',
#    '25787598',
#    '41611755',
#    '41611786',
#    '1589550',
#    '1589595',
#    '1589745',
#    '1589837',
#    '9514601',
#    '33645814',
#    '17545825',
#    '17545887',
#    '17545894',
#    '1591254',
#    '1592699',
#    '1592150',
#    '17545981',
#    '17546011',
#    '17546024',
#    '1591634',
#    '1591841',
#    '1591842',
#    '1591910',
#    '1593057',
#    '1593219',
#    '1593225',
#    '9514890',
#    '9515032',
#    '41611929',
#    '33646154',
#    '25787853',
#    '25787855',
#    '25787907',
#    '33646319',
#    '9514666',
#    '1592328',
#    '41611817',
#    '41611869',
#    '25787949',
#    '25788017',
#    '25788069',
#    '25787681',
#    '17546412',
#    '1593504',
#    '25788078',
#    '33646203',
#    '1592935',
#    '25788343',
#    '25788360',
#    '33646381',
#    '17546482',
#    '17546536',
#    '17546576',
#    '1593373',
#    '17546362',
#    '17546375',
#    '41612240',
#    '41612274',
#    '25788124',
#    '25788201',
#    '1593663',
#    '1593742',
#    '1593800',
#    '33646242',
#    '1594242',
#    '1594391',
#    '41612356',
#    '41612412',
#    '41612452',
#    '33646599',
#    '33646023',
#    '33646049',
#    '33646067',
#    '33646088',
#    '17546147',
#    '17546169',
#    '17546183',
#    '1594672',
#    '1594751',
#    '9515211',
#    '25788277',
#    '9515376',
#    '9515381',
#    '1595157',
#    '25788868',
#    '25788897',
#    '25788900',
#    '25788939',
#    '25788949',
#    '25788958',
#    '1596072',
#    '33646282',
#    '1595201',
#    '1595261',
#    '17547248',
#    '17547251',
#    '17547267',
#    '25789041',
#    '1595835',
#    '25788726',
#    '1594862',
#    '1594873',
#    '17546867',
#    '25788412',
#    '17547174',
#    '1596452',
#    '25788563',
#    '25788668',
#    '1595394',
#    '33668139',
#    '33668151',
#    '17575564',
#    '17575582',
#    '17575625',
#    '1696864',
#    '1696877',
#    '1696914',
#    '1696975',
#    '25788775',
#    '1595995',
#    '9543329',
#    '25817135',
#    '25817200',
#    '17575654',
#    '33668181',
#    '1697898',
#    '1697908',
#    '41633318',
#    '17575982',
#    '25788466',
#    '25788486',
#    '1594952',
#    '33668384',
#    '41633081',
#    '41633109',
#    '1697364',
#    '1697367',
#    '1697393',
#    '25817355',
#    '25817370',
#    '25817389',
#    '25817412',
#    '1697459',
#    '1697473',
#    '1696619',
#    '1696736',
#    '33668573',
#    '33668492',
#    '9543541',
#    '9543545',
#    '17576013',
#    '17576050',
#    '1697975',
#    '1697985',
#    '1697996',
#    '33668427',
#    '25817252',
#    '9543382',
#    '9543633',
#    '1699011',
#    '1699026',
#    '1699033',
#    '9544095',
#    '33668607',
#    '17576239',
#    '17576299',
#    '17576315',
#    '33668461',
#    '9543932',
#    '9543947',
#    '9543948',
#    '25817578',
#    '25817589',
#    '25817598',
#    '25817676',
#    '1698483',
#    '1698508',
#    '33668682',
#    '33668896',
#    '1699129',
#    '1699138',
#    '1699151',
#    '1699217',
#    '25817745',
#    '1699256',
#    '1699257',
#    '1699302',
#    '1699313',
#    '1699391',
#    '9543842',
#    '9543854',
#    '17576507',
#    '17576529',
#    '9544411',
#    '25817775',
#    '25817804',
#    '17576728',
#    '1698794',
#    '1698874',
#    '9544596',
#    '25817925',
#    '25817983',
#    '25818016',
#    '41633488',
#    '9543876',
#    '9543885',
#    '25818089',
#    '41633953',
#    '41633977',
#    '41633666',
#    '41633672',
#    '25817868',
#    '25817895',
#    '33669056',
#    '33669102',
#    '41633540',
#    '9544209',
#    '9544253',
#    '1700278',
#    '41633820',
#    '41633826',
#    '17576775',
#    '41633777',
#    '9544515',
#    '1700062',
#    '9544864',
#    '9544940',
#    '33669382',
#    '41634005',
#    '1700437',
#    '1700529',
#    '41634064',
#    '17576996',
#    '17577066',
#    '17576849',
#    '1700300',
#    '1700343',
#    '41634283',
#    '17577134',
#    '1700807',
#    '1700679',
#    '33669878',
#    '1701803',
#    '1701809',
#    '9545421',
#    '9545422',
#    '17577267',
#    '17577270',
#    '17577308',
#    '1702185',
#    '1702186',
#    '25818440',
#    '25818458',
#    '9545167',
#    '25818269',
#    '25818337',
#    '41634410',
#    '41634433',
#    '1701429',
#    '33669660',
#    '33669666',
#    '33669713',
#    '33669732',
#    '33669741',
#    '1701246',
#    '33669599',
#    '33669609',
#    '33669623',
#    '1701340',
#    '25818680',
#    '9545485',
#    '9545525',
#    '1702834',
#    '25818607',
#    '25818619',
#    '1701942',
#    '1701949',
#    '1701973',
#    '9545222',
#    '9545265',
#    '9545859',
#    '33670075',
#    '33669925',
#    '33670014',
#    '9545642',
#    '25818725',
#    '25818735',
#    '17577423',
#    '17577441',
#    '9544957',
#    '9545043',
#    '9545062',
#    '41634253',
#    '9545977',
#    '1703371',
#    '1702842',
#    '1703077',
#    '1703183',
#    '1703226',
#    '1703228',
#    '33670118',
#    '33670172',
#    '33670176',
#    '33670185',
#    '25818797',
#    '25818814',
#    '1702637',
#    '17577586',
#    '25818645',
#    '25819040',
#    '1702559',
#    '1702580',
#    '41634566',
#    '41634673',
#    '41634695',
#    '41634706',
#    '25819291',
#    '17577590',
#    '17577630',
#    '9546398',
#    '9546439',
#    '33670234',
#    '33670315',
#    '33670718',
#    '33670729',
#    '9546535',
#    '41634977',
#    '17577851',
#    '9546276',
#    '9546303',
#    '9546304',
#    '33670534',
#    '33670541',
#    '33670605',
#    '33670348',
#    '33670454',
#    '1703883',
#    '1703886',
#    '25819152',
#    '17577953',
#    '17577980',
#    '33670653',
#    '25819366',
#    '9546566',
#    '9546574',
#    '1704425',
#    '1704476',
#    '17578205',
#    '17578222',
#    '17578247',
#    '25819416',
#    '25819418',
#    '25819474',
#    '1704356',
#    '17578012',
#    '17578016',
#    '17578045',
#    '17578092',
#    '41634859',
#    '41634878',
#    '1703476',
#    '1703487',
#    '1703492',
#    '1703552',
#    '1704845',
#    '1705184',
#    '33671004',
#    '33670882',
#    '33670911',
#    '33670912',
#    ...])]

# %%
# Mapping function to count the number of ids for each tag:
step4 = step3.flatMap(lambda k: ([k[0],len(k[i])] for i in range(1,len(k))))
step4.take(5)
# Out:
# [['html', 1978],
#  ['footer', 10],
#  ['macos', 298],
#  ['gcc', 96],
#  ['android', 2594]]

# %% [markdown]
# ## Spark SQL and DataFrames

# %% [markdown]
# #### Double check the result above using SQL query on the original dataset:

# %%
from pyspark import SparkContext, SQLContext
from pyspark.sql.types import Row
from pyspark.sql import SparkSession

# %%
spark1 = SparkSession.builder.appName('Data_queries').config("spark.master","local").getOrCreate()
df1 = spark1.read.csv("QueryResults.csv",mode="DROPMALFORMED", inferSchema=True, header=False)
df1.show(5)
# Out:
# +-------+--------------------+
# |    _c0|                 _c1|
# +-------+--------------------+
# |1596943|<html><asp.net><f...|
# |1596945| <macos><gcc><otool>|
# |1596947|           <android>|
# |1596950|<c#><.net><wmi><d...|
# |1596951|<java><database><...|
# +-------+--------------------+
# only showing top 5 rows

# %%
df1.createOrReplaceTempView("StackOverflow")
sqlDF = spark1.sql("SELECT count(*) FROM StackOverflow where _c1 like '%<html>%'")
sqlDF.show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |    1978|
# +--------+

# %% [markdown]
# The result for the HTLM tag query is identical to the MapReduce result above. This confirms that **the script for Spark MapReduce worked correctly.**

# %% [markdown]
# ### Find the top 5 tags:

# %%
spark2 = SparkSession.builder.appName('Inverted_index').config("spark.master","local").getOrCreate()
df2 = spark2.createDataFrame(step4, schema = ['Tag', 'Count'])

# %%
# the order of sparkdf is random 
# I will perform a SQL query to find the most popular tags based on counts
df2.show(5)
# Out:
# +-------+-----+
# |    Tag|Count|
# +-------+-----+
# |   html| 1978|
# | footer|   10|
# |  macos|  298|
# |    gcc|   96|
# |android| 2594|
# +-------+-----+
# only showing top 5 rows

# %%
# Data Structure of the "Count" column is int64 (long)
# this allows sorting based on numeric values
df2.printSchema()
# Out:
# root
#  |-- Tag: string (nullable = true)
#  |-- Count: long (nullable = true)

# %%
# Using temporary df for SQL queries:
df2.createOrReplaceTempView("StackOverflow")
sqlDF = spark2.sql("SELECT COUNT(*) FROM StackOverflow")
sqlDF.show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |   12798|
# +--------+

# %%
# SQL query for the most popular tags:
sqlDF = spark2.sql("SELECT tag, count FROM StackOverflow ORDER BY count DESC")
sqlDF.show()
# Out:
# +-------------+-----+
# |          tag|count|
# +-------------+-----+
# |           c#| 4565|
# |         java| 4277|
# |   javascript| 4146|
# |          php| 3809|
# |       jquery| 2797|
# |      android| 2594|
# |       python| 2390|
# |          c++| 2056|
# |         html| 1978|
# |        mysql| 1693|
# |      asp.net| 1585|
# |          sql| 1558|
# |         .net| 1504|
# |          css| 1473|
# |          ios| 1302|
# |       iphone| 1155|
# |            c| 1102|
# |ruby-on-rails| 1030|
# |  objective-c|  963|
# |   sql-server|  831|
# +-------------+-----+
# only showing top 20 rows

# %% [markdown]
# ### So what are the 5 most popular tags?
#
#  From this project, I found out that C# was the most popular tag on Stack Overflow recently.
#
#  The top 5 tags include c#, java, javascript, php and jquery. My favorite language - Python, is at the 7th place on this list.

# %% [markdown]
# ## Additional queries and analysis:
#
# SQL query for this extension: SELECT Id, Title FROM Posts WHERE Tags is not null;
#
# ### Find the most common words in the title of each Stack overflow tag:
#
# In this extension of the project, I would to know more about the common words that appear in the titles of the post. These popular words often reflect the topics of interest that related to each tag. In order to obtain this information, I will perform the word count problem using Spark MapReduce. Some additional packages include NLTK to clean up the words and Counter package for counting words in the title.
#
# **Question: What are the top 5 words in the titles of each tag? Do these words make sense in the context of each tag?**

# %%
sc.stop() # need to stop the running Spark Context before starting a new one 
sc = pyspark.SparkContext(appName="Title Word Count") 
text_file = sc.textFile("QueryResults2.csv")

# %%
# step1 - preprocessing: split by commas
step1 = text_file.map(lambda x: x.split(",")).map(lambda y: [y[0].replace('-',''),y[1]])
step1.take(3)
# Out:
# [['How to use a variable storing an equal sign in an SQL query', '<php><sql>'],
#  ['Javascript remote src not working', '<javascript>'],
#  ['How to svn dump a specific folder and load it into a specific location',
#   '<svn><tortoisesvn><svnadmin>']]

# %%
# step2: further split the tags
step2 = step1.map(lambda x: (x[0],x[1].replace('<', ' ').replace('>','').split()))
step2.take(1)
# Out:
# [('How to use a variable storing an equal sign in an SQL query',
#   ['php', 'sql'])]

# %%
# step3: mapping the title to each tag separately 
step3 = step2.flatMap(lambda w: ((x,w[0]) for x in w[1]))
step3.take(5)
# Out:
# [('php', 'How to use a variable storing an equal sign in an SQL query'),
#  ('sql', 'How to use a variable storing an equal sign in an SQL query'),
#  ('javascript', 'Javascript remote src not working'),
#  ('svn',
#   'How to svn dump a specific folder and load it into a specific location'),
#  ('tortoisesvn',
#   'How to svn dump a specific folder and load it into a specific location')]

# %%
# step4: reduce by tag, adding up all the words in all the titles of that tag
# notice that the list contains stopwords such as "to", "a", "in", etc,. 
step4 = step3.reduceByKey(lambda total, count: total + ',' + count).map(lambda x: (x[0],x[1].lower().replace(",",'').split()))
step4.take(5)
# Out:
# [('php',
#   ['how',
#    'to',
#    'use',
#    'a',
#    'variable',
#    'storing',
#    'an',
#    'equal',
#    'sign',
#    'in',
#    'an',
#    'sql',
#    'querysplit',
#    'sentence',
#    'into',
#    'character',
#    'limited',
#    'arraysfile_get_contents',
#    'failure',
#    'on',
#    'windowsmysql',
#    'selecting',
#    'random',
#    'rows',
#    'with',
#    'one',
#    'unique',
#    'row',
#    'within',
#    'one',
#    'querysoap',
#    'and',
#    'ntlm',
#    'authentication',
#    'between',
#    'debian',
#    'an',
#    'iis',
#    'serverphp',
#    'file',
#    'renamephp:',
#    'is',
#    'it',
#    'possible',
#    'to',
#    'retrieve',
#    'the',
#    'class',
#    'name',
#    'of',
#    'a',
#    'child',
#    'class?greek',
#    'character',
#    'insertion',
#    'in',
#    'php',
#    'compared',
#    'to',
#    'sql',
#    'server',
#    'management',
#    'studiocheck',
#    'for',
#    'malicious',
#    'xml',
#    'before',
#    'allowing',
#    'dtd',
#    'loading?mysql',
#    'data',
#    'query',
#    'is',
#    'not',
#    'refreshingreplacing',
#    'wordpress',
#    'footer',
#    'with',
#    'custom',
#    'html',
#    'onemysql',
#    'results',
#    'getting',
#    'repeated',
#    'when',
#    'comparing',
#    'with',
#    'the',
#    'results',
#    'of',
#    'loopphp',
#    'mysql',
#    'login',
#    'header',
#    'issue$stmt',
#    '=',
#    '$conn>prepare($sql)',
#    'returns',
#    'me',
#    'undefined',
#    '$stmt',
#    'var',
#    '(solved)woocommerce',
#    'custom',
#    'shop',
#    'page',
#    '(archiveproduct.php)',
#    'and',
#    'search',
#    'results',
#    'pagehow',
#    'bootstrap',
#    'modal',
#    'get',
#    "'id'",
#    'from',
#    'urllinux',
#    'php',
#    'extractto',
#    'returns',
#    'whole',
#    'path',
#    'instead',
#    'of',
#    'the',
#    'file',
#    'structuredoes',
#    "abraham's",
#    'twitteroauth',
#    'library',
#    'work',
#    'for',
#    'update_with_media?php',
#    'pdo',
#    'mysql',
#    'execute();laravel',
#    'config::get()',
#    'from',
#    'particular',
#    'environment',
#    '(not',
#    'current)how',
#    'would',
#    'you',
#    'implement',
#    'form',
#    'based',
#    'authentication',
#    'without',
#    'a',
#    'backing',
#    'database?how',
#    'to',
#    'import',
#    'file',
#    'contents',
#    'into',
#    'nodeimage',
#    'ajax',
#    'search',
#    'not',
#    'working',
#    'in',
#    'safarisending',
#    'a',
#    'high',
#    'and',
#    'low',
#    'price',
#    'limit',
#    'through',
#    'a',
#    'linkprotect',
#    'login',
#    'when',
#    'https',
#    'is',
#    'not',
#    'availabletrack',
#    'changes',
#    'to',
#    'mysql',
#    'table',
#    'using',
#    'node.js"""',
#    "'",
#    '""',
#    'being',
#    'converted',
#    'into',
#    '""',
#    '&#8216;',
#    '"""multiple',
#    'order',
#    'statement',
#    'mysqlfile_get_contents',
#    'url',
#    'now',
#    'too',
#    'longphp',
#    'return_var',
#    'codes?need',
#    'a',
#    'way',
#    'to',
#    'check',
#    'to',
#    'see',
#    'if',
#    'a',
#    'wildcard',
#    'string',
#    'matches',
#    'a',
#    'given',
#    'string',
#    'in',
#    'phpinsert',
#    'record',
#    'and',
#    'image',
#    'with',
#    'php',
#    'and',
#    'jqueryauto',
#    'complete',
#    'fields',
#    'of',
#    'a',
#    'previous',
#    'valuesurl',
#    'rewrite:',
#    'multiple',
#    'addresses',
#    'per',
#    'articlecreate',
#    'multipal',
#    'website',
#    'in',
#    'magentoselecting',
#    'the',
#    'text',
#    'in',
#    'the',
#    'datagrid',
#    'and',
#    'copying',
#    'to',
#    'the',
#    'message',
#    'box',
#    'in',
#    'the',
#    'other',
#    'php',
#    'pagephp',
#    'mysql',
#    'data',
#    'base',
#    'retrieval',
#    'three',
#    'records',
#    'in',
#    'one',
#    'rowsonata',
#    'admin',
#    'for',
#    'symfony2',
#    'performancereturning',
#    'a',
#    'random',
#    'value',
#    'from',
#    'array',
#    'with',
#    'probability',
#    'proportional',
#    'to',
#    "it's",
#    'valuetroubles',
#    'while',
#    'splitting',
#    'a',
#    'stringpassing',
#    'and',
#    'capture',
#    'url',
#    'variables',
#    'jquery',
#    'without',
#    'phpzend',
#    'framework',
#    '2.3',
#    'translate',
#    'formcalculate',
#    'the',
#    'dynamic',
#    'values',
#    'of',
#    'rate',
#    '*',
#    'quantityvalidate',
#    'uk',
#    'short',
#    'postcodeget',
#    'array',
#    'elements',
#    'dynamically',
#    'based',
#    'on',
#    'checkbox',
#    'checked?how',
#    'to',
#    'load',
#    'mysql',
#    'data',
#    'on',
#    'separate',
#    'formsphp',
#    'function',
#    'not',
#    'reaching',
#    'the',
#    'innermost',
#    'nested',
#    'if',
#    'blocklaravel',
#    '3:',
#    'having',
#    'difficulty',
#    'getting',
#    'my',
#    'head',
#    'wrapped',
#    'around',
#    'the',
#    '`has_one()`',
#    'relationshipini_set',
#    'include_path',
#    'not',
#    'workinginvalid',
#    'argument',
#    'supplied',
#    'for',
#    'foreach;',
#    'pdosimple',
#    'comment',
#    'box',
#    'php',
#    'and',
#    'mysql',
#    "didn't",
#    'workdeprecated',
#    'php',
#    '$http_post_fileshow',
#    'to',
#    'retrieve',
#    'one',
#    'row/one',
#    'field',
#    'using',
#    'php',
#    'mysql_fetch_arrayhow',
#    'to',
#    'call',
#    'methods',
#    'in',
#    'php',
#    'from',
#    'xmlwhere',
#    'does',
#    'the',
#    'php',
#    'file()',
#    'function',
#    'get',
#    'line',
#    'numbers?how',
#    'to',
#    'enable',
#    'utf',
#    '8',
#    'support',
#    'pcre',
#    'xampp',
#    'for',
#    'windows?html',
#    'link',
#    'tr',
#    'broken',
#    'not',
#    'on',
#    'placehow',
#    'to',
#    'get',
#    'dropdown',
#    'selected',
#    'value',
#    'and',
#    'pass',
#    'to',
#    'mysql',
#    'query?how',
#    'to',
#    'achive',
#    'this',
#    'scenario:',
#    'paypal',
#    'recurring',
#    '+',
#    'trial',
#    'period',
#    '+',
#    'base',
#    'priceusing',
#    'an',
#    'alternative',
#    'sidebar',
#    'when',
#    'creating',
#    'a',
#    'wordpress',
#    'themeplupload:',
#    'get',
#    'data',
#    'attributes',
#    'of',
#    'multiple',
#    'dynamic',
#    'dropzoneswordpress',
#    'page',
#    'not',
#    'working',
#    'after',
#    'changing',
#    'hostingsimple',
#    'html',
#    'dom',
#    'space',
#    'in',
#    'classuser',
#    'rights',
#    'in',
#    'my',
#    'cmsyii',
#    'ajax',
#    'form',
#    'submition',
#    'without',
#    'inline',
#    'script$this>forward',
#    'looses',
#    'the',
#    "user's",
#    'requested',
#    'route?cakephp',
#    'misterious',
#    'automatic',
#    'validation',
#    'rule',
#    'on',
#    'fieldmysql',
#    'select',
#    'content',
#    'in',
#    'multiple',
#    'languagesdealing',
#    'with',
#    'php',
#    'server',
#    'and',
#    'mysql',
#    'server',
#    'in',
#    'different',
#    'time',
#    'zoneshow',
#    'to',
#    'use',
#    'insecure',
#    'web',
#    'script',
#    'on',
#    'ssl',
#    'pagesimage',
#    'is',
#    'not',
#    'storing',
#    'in',
#    'mysql',
#    'database',
#    'via',
#    'phpphpunit',
#    'code',
#    'coverage',
#    'on',
#    'interfaces',
#    'shows',
#    'no',
#    'successpdo',
#    'object',
#    'rows',
#    'printing',
#    'twicefrom',
#    'address',
#    'come',
#    'with',
#    'server',
#    'extension',
#    'in',
#    'mailmysqii',
#    'select',
#    'count',
#    'and',
#    'order',
#    'by',
#    'countsending',
#    'mail',
#    'using',
#    'php',
#    'and',
#    'pear',
#    'on',
#    'windowsphp/mysql',
#    'queries',
#    'vs',
#    'arrays?php/ajax',
#    'advice',
#    'on',
#    'replacing',
#    'iframe',
#    'with',
#    'div',
#    '(combined',
#    'with',
#    'ajax)jquery',
#    'table',
#    'pagination',
#    '(mysql',
#    '+',
#    'php)uploading',
#    'pdf',
#    'files',
#    'in',
#    'php',
#    '5.4',
#    'and',
#    'kcfindervalidating',
#    'html',
#    'dropdown',
#    'menu',
#    'with',
#    'javascript?query',
#    'syntax',
#    'with',
#    'php',
#    'variables',
#    'to',
#    'select',
#    'from',
#    'two',
#    'mysql',
#    'tableshow',
#    'to',
#    'return',
#    'the',
#    'class',
#    'of',
#    'an',
#    'element?jquery',
#    'datatables',
#    'â€“',
#    'click',
#    'event',
#    'handler',
#    'not',
#    'working',
#    'for',
#    '2nd',
#    'page',
#    'of',
#    'paginationbrowser',
#    'back',
#    'button',
#    'in',
#    'a',
#    'silex',
#    "applicationcan't",
#    'access',
#    'variables',
#    'from',
#    '_bootstrap.php',
#    'in',
#    'codeceptionlimit',
#    'submitting',
#    'many',
#    'requests',
#    'ajax',
#    'php',
#    'formphp',
#    'array',
#    'values',
#    'distribution',
#    'near',
#    'averageconvert',
#    'rgb',
#    'to',
#    'html',
#    'named',
#    'colors',
#    'with',
#    'phphow',
#    'insert',
#    'and',
#    'retrieve',
#    'images',
#    'to',
#    'and',
#    'from',
#    'database',
#    'using',
#    'phpphp',
#    'converting',
#    'a',
#    'date',
#    'to',
#    'timestamp',
#    'using',
#    'datetime',
#    'decreases',
#    '1',
#    'day',
#    'weirdis_file()',
#    'and',
#    'local',
#    'file',
#    'inclusion',
#    'vulnerabilityphp',
#    'return',
#    'value',
#    'from',
#    'recursive',
#    'functionhow',
#    'can',
#    'i',
#    'merge',
#    '3',
#    'csv',
#    'files',
#    'into',
#    '1',
#    'csv',
#    'file',
#    'using',
#    'php?"how',
#    'to',
#    'display',
#    '""12',
#    'minutes',
#    'ago""',
#    'etc',
#    'in',
#    'a',
#    'php',
#    'webpage?"batch',
#    'code',
#    'indenters',
#    'and',
#    'beautifiershaving',
#    'issue',
#    'getting',
#    'custom',
#    'console',
#    'commands',
#    'to',
#    'work',
#    'in',
#    'yii2',
#    'whilst',
#    'running',
#    'multiple',
#    'applicationsajax',
#    'check',
#    'registered',
#    'email',
#    'on',
#    'formphp',
#    'script',
#    'to',
#    'populate',
#    'mysql',
#    'tables"web',
#    'and',
#    'database',
#    'server',
#    'settings',
#    'to',
#    'get',
#    'utc',
#    'timezone',
#    '""right"""php',
#    'multithreadinghow',
#    'to',
#    'compare',
#    'strings',
#    'without',
#    'using',
#    'mysql',
#    'queries?looping',
#    'of',
#    'tables',
#    'when',
#    'search',
#    'button',
#    'is',
#    'presshow',
#    'to',
#    'add',
#    'email',
#    'function',
#    'to',
#    'this',
#    'php',
#    'checking',
#    'script?logging',
#    'out',
#    'a',
#    'user',
#    'completely',
#    'from',
#    'a',
#    'websitechange',
#    'relative',
#    'url',
#    'with',
#    'curlphp',
#    'class',
#    'works',
#    'with',
#    'chrome',
#    'but',
#    'not',
#    'with',
#    'firefoxajax',
#    'not',
#    'returning',
#    'result',
#    'from',
#    'phperror',
#    'in',
#    'uploading',
#    'large',
#    'file',
#    '(php)i',
#    'want',
#    'to',
#    'clear',
#    'contents',
#    'of',
#    'file',
#    'in',
#    'chrome',
#    'extension',
#    'and',
#    'the',
#    'file',
#    'is',
#    'on',
#    'server.',
#    'how',
#    'to',
#    'do',
#    'that?using',
#    'eval()',
#    'and',
#    'protecting',
#    'it',
#    'in',
#    'phpphp',
#    'to',
#    'check',
#    'the',
#    'location',
#    'the',
#    'email',
#    'is',
#    'sent',
#    'as',
#    'well',
#    'as',
#    'if',
#    'he',
#    'email',
#    'has',
#    'bouncedundefined',
#    'variable:',
#    'con',
#    'in',
#    'c:\\wamp\\www\\android_connect\\db_connect.php',
#    'on',
#    'line',
#    '<i>48</i>check',
#    'file',
#    'permissionsintroducing',
#    'pythonfast(er)',
#    'way',
#    'to',
#    'get',
#    'file',
#    'inode',
#    'using',
#    'phpregex',
#    'for',
#    'breadcrumb',
#    'in',
#    'phpjquery',
#    'ui',
#    'changing',
#    'source',
#    'to',
#    'mysql',
#    'datagoto',
#    'command',
#    'in',
#    'php?tools',
#    'for',
#    'php',
#    'code',
#    'refactoringphpmyadmin:',
#    'automatically',
#    'open',
#    'a',
#    'specific',
#    'table',
#    'once',
#    'logged',
#    'inallow',
#    'users',
#    'to',
#    'plot',
#    'points',
#    'on',
#    'a',
#    'google',
#    'map',
#    '(with',
#    'php/ajax)cakephp',
#    'exceptionsmarty',
#    'if',
#    'url',
#    'containshow',
#    'to',
#    'write',
#    'session',
#    'for',
#    'both',
#    'www.',
#    'and',
#    'nonwww',
#    'version',
#    'of',
#    'my',
#    'domain?mysql',
#    'query',
#    'for',
#    'each',
#    'of',
#    'the',
#    'values',
#    'of',
#    'an',
#    'arrayhow',
#    'to',
#    'automatically',
#    'bring',
#    'forward',
#    'january',
#    'marks',
#    'to',
#    'february',
#    'marks',
#    'field',
#    'after',
#    'the',
#    'month',
#    'of',
#    'january',
#    'ends?"i\'m',
#    'not',
#    'getting',
#    'the',
#    'data',
#    'from',
#    'the',
#    '$_files[""file""][""type""]',
#    'and',
#    '$_files[""file""][""size""]',
#    'even',
#    'though',
#    '$_files[""file""][""name""]',
#    'is',
#    'retuning',
#    'the',
#    'filename"ask',
#    'different',
#    'badges',
#    'to',
#    'product',
#    'on',
#    'shopify?difference',
#    'between',
#    '2',
#    'timestamps',
#    'in',
#    'days',
#    'from',
#    'mysql',
#    'table',
#    'with',
#    'user',
#    'session',
#    'loginsending',
#    'a',
#    'put',
#    'command',
#    'with',
#    'curl',
#    'on',
#    'phpwhere',
#    'does',
#    'visual',
#    'composer',
#    'store',
#    'links?why',
#    'does',
#    'safari/webkit',
#    'appends',
#    '.html',
#    'to',
#    'downloaded',
#    'files?doctrine',
#    'register',
#    'custom',
#    'dql',
#    'functionsmultiple',
#    'dropdowns',
#    'populated',
#    'by',
#    'one',
#    'related',
#    'table',
#    'cakephp',
#    '3php',
#    'error',
#    'class',
#    "'google_http_request'",
#    'not',
#    'foundcss',
#    'on',
#    'external',
#    'url',
#    'read',
#    'by',
#    'site',
#    'but',
#    'font',
#    'definitions',
#    'not',
#    'accesseduse',
#    'dynamically',
#    'created',
#    'form',
#    'values',
#    'to',
#    'set',
#    'variables',
#    'as',
#    'post',
#    'requests',
#    'in',
#    'phpupload',
#    'avi',
#    'php',
#    'errorsphp',
#    'random',
#    'set',
#    'of',
#    'imagesserialize()',
#    'and',
#    '$_session"how',
#    'to',
#    'loop',
#    'through',
#    'a',
#    'database',
#    'table',
#    'and',
#    'select',
#    'everything',
#    'with',
#    ...]),
#  ('svn',
#   ['how',
#    'to',
#    'svn',
#    'dump',
#    'a',
#    'specific',
#    'folder',
#    'and',
#    'load',
#    'it',
#    'into',
#    'a',
#    'specific',
#    'locationsetting',
#    '&',
#    'finding',
#    'a',
#    'svn',
#    'repository',
#    'on',
#    'a',
#    'system',
#    'in',
#    'lanankhsvn',
#    'cannot',
#    'connect',
#    'due',
#    'to',
#    'proxyhow',
#    'do',
#    'i',
#    'find',
#    'a',
#    'file',
#    'in',
#    'a',
#    'subversion',
#    'repository',
#    'history?repository',
#    'layout',
#    'for',
#    'large',
#    'maven',
#    'projectsscript',
#    'to',
#    'backup',
#    'svn',
#    'repository',
#    'to',
#    'network',
#    'sharelimit',
#    'user',
#    'access',
#    'to',
#    'repositories',
#    'on',
#    'assembla',
#    'or',
#    'another',
#    'svn',
#    'hosting',
#    'servicehow',
#    'do',
#    'i',
#    'implement',
#    'a',
#    'precommit',
#    'hook',
#    'script',
#    'in',
#    'svn',
#    'that',
#    'calls',
#    'dos2unix',
#    'to',
#    'validate',
#    'checkedin',
#    'fileis',
#    'there',
#    'any',
#    'way',
#    'to',
#    'get',
#    "'recent",
#    "messages'",
#    'while',
#    'commiting',
#    'using',
#    'svn',
#    'command',
#    'line',
#    'in',
#    'windowswhat',
#    'is',
#    'a',
#    'good',
#    'repository',
#    'layout',
#    'for',
#    'releases',
#    'and',
#    'projects',
#    'in',
#    'subversion?how',
#    'do',
#    'i',
#    'export',
#    '(and',
#    'then',
#    'import)',
#    'a',
#    'subversion',
#    'repository?using',
#    'a',
#    'wiki',
#    'as',
#    'a',
#    'central',
#    'development',
#    'project',
#    'repositorysource',
#    'control',
#    'for',
#    'everyone?better',
#    'merge',
#    'tool',
#    'for',
#    'subversioncan',
#    'i',
#    'have',
#    'tortoisesvn',
#    'autoadd',
#    'files?can',
#    'you',
#    'do',
#    'a',
#    'partial',
#    'checkout',
#    'with',
#    'subversion?running',
#    'a',
#    'command',
#    'in',
#    'the',
#    'cmd',
#    'in',
#    'the',
#    'background',
#    'of',
#    'a',
#    'windows',
#    'form',
#    'applicationmove',
#    'mixture',
#    'of',
#    'versioned',
#    'and',
#    'unversioned',
#    'files',
#    'and',
#    'foldersrecommendations',
#    'regarding',
#    'continuous',
#    'integration',
#    'systemsignore',
#    'svn',
#    'ignore...',
#    'possible?is',
#    'version',
#    'control',
#    'necessary',
#    'for',
#    'a',
#    'small',
#    'development',
#    'group',
#    '(12',
#    'programmers)?mirroring',
#    'perforce',
#    'with',
#    'svk?changing',
#    'the',
#    'directory',
#    'structure',
#    'in',
#    'subversionhow',
#    'do',
#    'i',
#    'implement',
#    'the',
#    'post',
#    'commit',
#    'hook',
#    'with',
#    'trac',
#    '&',
#    'svn',
#    'in',
#    'a',
#    'windows',
#    'environment?using',
#    'actionbarsherlock',
#    'with',
#    'subversionbest',
#    'way',
#    'to',
#    'set',
#    'up',
#    'cruisecontrol',
#    'for',
#    'iis',
#    '5.1',
#    'dev',
#    'box',
#    'and',
#    'iis6',
#    'serverbest',
#    'general',
#    'svn',
#    'ignore',
#    'pattern?adding',
#    'a',
#    'svn',
#    'repository',
#    'in',
#    'eclipseuse',
#    'current',
#    'subversion',
#    'slave',
#    'server',
#    'as',
#    'master',
#    'serverhow',
#    'do',
#    'i',
#    'ignore',
#    'files',
#    'in',
#    'subversion?good',
#    'linux',
#    '(ubuntu)',
#    'svn',
#    'clientcan',
#    'you',
#    'specify',
#    'filenames',
#    'using',
#    'wildcards',
#    'or',
#    'regexes',
#    'in',
#    'the',
#    'subversion',
#    'mv',
#    'command?what',
#    'is',
#    'your',
#    'preferred',
#    'method',
#    'for',
#    'moving',
#    'directory',
#    'structures',
#    'around',
#    'in',
#    'subversion?svn',
#    'checkout',
#    'questionhow',
#    'do',
#    'you',
#    'overcome',
#    'the',
#    'svn',
#    "'out",
#    'of',
#    "date'",
#    'error?can',
#    'i',
#    'merge',
#    'two',
#    'microsoft',
#    'word',
#    'documents',
#    'reliably',
#    'with',
#    'subversion?can',
#    'i',
#    'see',
#    'the',
#    'currently',
#    'checked',
#    'out',
#    'revision',
#    'number',
#    'in',
#    'tortoise',
#    'svn?why',
#    'does',
#    'mvn',
#    'release:prepare',
#    'fail',
#    'while',
#    'tagging?clean',
#    'builds',
#    'in',
#    'continuous',
#    'integrationhow',
#    'do',
#    'i',
#    'use',
#    'textmate',
#    'as',
#    'my',
#    'command',
#    'line',
#    'subversion',
#    'message',
#    'editor?how',
#    'do',
#    'i',
#    'ensure',
#    'the',
#    'mvn',
#    'release',
#    'plugin',
#    "won't",
#    'build',
#    'with',
#    'uncommitted',
#    'changes',
#    'for',
#    'a',
#    'custom',
#    'packaging',
#    "typewhat's",
#    'the',
#    'difference',
#    'between',
#    'subclipse',
#    'get',
#    'contents',
#    'and',
#    'get',
#    'revision?moving',
#    'from',
#    'vss',
#    'to',
#    'svnssh',
#    'access',
#    'to',
#    'a',
#    'ubuntu',
#    'box',
#    'with',
#    'no',
#    'terminalhow',
#    'to',
#    'switch',
#    'back',
#    'to',
#    'a',
#    'previous',
#    'version',
#    'of',
#    'a',
#    'file',
#    'without',
#    'deleting',
#    'its',
#    'subsequent',
#    'revisions?svn:',
#    'module',
#    'organization',
#    'early',
#    'in',
#    'the',
#    'development',
#    'processsvn',
#    'option/plugin',
#    'that',
#    "won't",
#    'allow',
#    'commit',
#    'if',
#    'files',
#    'contain',
#    'certain',
#    'stringmerging',
#    "users'",
#    'history',
#    'in',
#    'svn<rctbridgemodule.h>',
#    "can't",
#    'be',
#    'found',
#    'for',
#    'ios',
#    'buildhow',
#    'to',
#    'recover',
#    'repository',
#    'using',
#    'svn',
#    'hotcopy?avoiding',
#    'svn',
#    'recursive',
#    'checkout',
#    'of',
#    'externalsable',
#    'to',
#    'delete',
#    'a',
#    'specific',
#    'revision',
#    'from',
#    'svn?"how',
#    'can',
#    'i',
#    'fix',
#    'this',
#    'svn',
#    'commit',
#    'which',
#    'fails',
#    'as',
#    '""out',
#    'of',
#    'date""?"tortoise',
#    'svn',
#    'requires',
#    'many',
#    'tries',
#    'to',
#    'do',
#    'anythingsvn',
#    'client',
#    'checkout',
#    'errorsregex',
#    'to',
#    'determine',
#    'branch',
#    'from',
#    'svn',
#    'repository',
#    'urlwhat',
#    'is',
#    'the',
#    'correct',
#    'way',
#    'to',
#    'handle',
#    'repeated',
#    'merges',
#    'of',
#    'an',
#    'svn',
#    'branch?how',
#    'can',
#    'i',
#    'use',
#    'find',
#    'to',
#    'recursively',
#    'backup',
#    'multiple',
#    'subversion',
#    'repositorieshow',
#    'to',
#    'use',
#    'svn(subversion)',
#    'with',
#    'vcs',
#    'gutter',
#    'plugin',
#    'in',
#    'sublime',
#    'text',
#    '3',
#    'on',
#    'windows',
#    '7?identical',
#    'consecutive',
#    'commit',
#    'messages',
#    'from',
#    'the',
#    'same',
#    'userdisplay',
#    'a',
#    'folder',
#    'in',
#    'visual',
#    'studioscript',
#    'to',
#    'add',
#    'files',
#    'to',
#    'svn',
#    'with',
#    'filterstrac',
#    'svnauthzadminplugin',
#    'install',
#    'erroris',
#    'there',
#    'an',
#    'equivalent',
#    'to',
#    'flashbake',
#    '(easy',
#    'version',
#    'control)',
#    'for',
#    'perforce',
#    'or',
#    'subversionsvn',
#    'log',
#    'missing',
#    'revisionscan',
#    'you',
#    'combine',
#    'revisions',
#    'with',
#    'subversionbest',
#    'way',
#    'to',
#    'manage',
#    'multiple',
#    'apps',
#    'in',
#    'subversionhow',
#    'do',
#    'i',
#    'find',
#    'if',
#    'a',
#    'file',
#    'have',
#    'ever',
#    'existed',
#    'in',
#    'a',
#    'svnrepo?how',
#    'do',
#    'you',
#    'setup',
#    'svn',
#    'for',
#    'general',
#    'website',
#    'development/deployment?mysterious',
#    'nonchange',
#    'showing',
#    'up',
#    'in',
#    'tortoisesvn',
#    '/',
#    'tortoisemergeworking',
#    'with',
#    'large',
#    'size',
#    'branches',
#    'of',
#    'svnhow',
#    'can',
#    'i',
#    'allow',
#    'users',
#    'to',
#    'run',
#    'a',
#    'website',
#    'without',
#    'adding',
#    'its',
#    'bin',
#    'folder',
#    'to',
#    'svn?python',
#    '+',
#    'svn',
#    '+',
#    'windows/mac',
#    '=',
#    'invalid',
#    'syntax?how',
#    'to',
#    'revert',
#    'one',
#    'commit',
#    'from',
#    'a',
#    'reintegrated',
#    'branch?eclipse',
#    'project',
#    'management',
#    'with',
#    'svnxcode',
#    'and',
#    'svn',
#    'client',
#    'certificateshow',
#    'do',
#    'i',
#    'check',
#    'out',
#    'a',
#    'subversion',
#    'repository',
#    'from',
#    'a',
#    'network',
#    'share?"xcode',
#    '4.3',
#    '>',
#    'svn',
#    'issue',
#    '""project',
#    'has',
#    'no',
#    'default',
#    'build',
#    'configuration"""svn',
#    "won't",
#    'let',
#    'me',
#    'commit',
#    'moved',
#    'tree',
#    'because',
#    'of',
#    'one',
#    'filegoogle',
#    'code',
#    'email',
#    'notificationsvn',
#    'copy',
#    'problem',
#    'with',
#    'directoriesinstalling',
#    'trac',
#    'with',
#    'subversion',
#    '1.6"svn',
#    'subversion',
#    'exception',
#    '""svn:',
#    'options',
#    'of',
#    "'https://www.mymachine.com/svn/",
#    "':",
#    'could',
#    'not',
#    'connect',
#    'to',
#    'server',
#    '(https://www.mymachine.com',
#    ')"""determine',
#    'total',
#    'size',
#    'of',
#    'svn',
#    'directory/trunksubclipse',
#    'checkout',
#    'svn',
#    'repository',
#    'into',
#    'a',
#    'nonroot',
#    'folderlearning',
#    'svn',
#    'simple',
#    'beginner',
#    'questionshow',
#    'to',
#    'make',
#    'svn',
#    'diff',
#    'show',
#    'only',
#    'nonwhitespace',
#    'line',
#    'changes',
#    'between',
#    'two',
#    'revisionshow',
#    'do',
#    'you',
#    'get',
#    'the',
#    'current',
#    'user',
#    'logged',
#    'in',
#    'to',
#    'an',
#    'apache',
#    'realm?using',
#    'cruisecontrol.net',
#    'and',
#    'svn',
#    'suddenly',
#    'getting',
#    'access',
#    'to',
#    'path',
#    'is',
#    'denied',
#    'during',
#    'build',
#    'processsubversion:',
#    'batching',
#    'up',
#    'createdirectory',
#    'changes',
#    'into',
#    'a',
#    'single',
#    'commitsafely',
#    'move',
#    'svn',
#    'folders',
#    'and',
#    'filescreated',
#    '/',
#    'modified',
#    'date',
#    "doesn't",
#    'change',
#    'if',
#    'i',
#    'copy',
#    'and',
#    'overwrite',
#    'a',
#    'destination',
#    'file',
#    'in',
#    'windowssvn',
#    ':',
#    'export',
#    'modified',
#    'files',
#    'of',
#    'revisions',
#    'committed',
#    'with',
#    'specific',
#    'commentsvn',
#    'operation',
#    'time',
#    'on',
#    'vista/windows',
#    '7/2008',
#    'rc2wrong',
#    'tag',
#    'with',
#    'maven',
#    'release',
#    'plugin',
#    'and',
#    'multi',
#    'module',
#    'projectsliksvn',
#    '+',
#    'windows',
#    '2008',
#    'servereasiest',
#    'way',
#    'to',
#    'collect',
#    'revision',
#    'history',
#    'since',
#    'last',
#    'merge',
#    'in',
#    "subversioncan't",
#    'rename',
#    'project',
#    'tortoisesvn',
#    '&',
#    'subversionhow',
#    'to',
#    'checout',
#    'from',
#    'ip?',
#    'svnhooking',
#    'into',
#    'svn',
#    'in',
#    'a',
#    'asp.net',
#    'web',
#    'applicationhow',
#    'to',
#    'use',
#    'downloadsvn',
#    'fatortoise',
#    'svn',
#    'version',
#    '1.7.7.17493',
#    'show',
#    'log',
#    'not',
#    'workingfind',
#    'checked',
#    'out',
#    'files',
#    'and',
#    'users',
#    'in',
#    'svnssis',
#    'version',
#    'controlling',
#    '+',
#    'subversionissues',
#    'in',
#    'merging',
#    'brancheseclipse',
#    'plugin',
#    'to',
#    'copy',
#    'names',
#    'of',
#    'committed',
#    'classesconfigure',
#    'svn',
#    'for',
#    'flash',
#    'action',
#    'script',
#    'programmingwhat',
#    'is',
#    'a',
#    '(xcode)',
#    'svn',
#    'repository',
#    'and',
#    'how',
#    'to',
#    'use',
#    'itunable',
#    'to',
#    'start',
#    'subversion',
#    'on',
#    'windows',
#    '2003',
#    'server.',
#    'startservice',
#    'failed',
#    '1053cvs2svn',
#    'for',
#    'only',
#    'one',
#    'revisionhow',
#    'can',
#    'i',
#    'write',
#    'a',
#    'wrapper',
#    'script',
#    'to',
#    'create',
#    'an',
#    'svn',
#    'branch?reintegrate',
#    'a',
#    'branch',
#    'vs',
#    'merge',
#    'a',
#    'range',
#    'of',
#    'revision"svn',
#    'copy',
#    'returns',
#    '""repository',
#    'moved',
#    'permanetly"""svn',
#    'merge',
#    'between',
#    '2',
#    'branch',
#    'which',
#    'are',
#    'created',
#    'from',
#    'different',
#    'sourcegetting',
#    'django',
#    'and',
#    'subversion',
#    'to',
#    'work',
#    'together',
#    'on',
#    'dreamhostssis',
#    'packages',
#    'version',
#    'controllingdeploying',
#    'to',
#    'appharbor',
#    'using',
#    'subversiontortoise',
#    "won't",
#    'connect',
#    'to',
#    'subversion',
#    'servertrac',
#    'task',
#    'context',
#    'sharing',
#    'with',
#    'mylynfailed',
#    'importing',
#    'code',
#    'from',
#    'svn',
#    'to',
#    'git',
#    'svn',
#    'trunk',
#    'is',
#    'emptymultiple',
#    'svn',
#    'repositories',
#    'or',
#    'single',
#    'company',
#    'repositoryconfiguring',
#    'multiple',
#    'build',
#    'configurations',
#    'from',
#    'shared',
#    'vcs',
#    'root',
#    'in',
#    'teamcityversion',
#    'control',
#    'with',
#    'file',
#    'level',
#    'controlwhich',
#    'vcs',
#    'should',
#    'i',
#    'use',
#    'with',
#    'google',
#    'code?import',
#    'separate',
#    'svn',
#    'directories',
#    'as',
#    'git',
#    'branchesmodify',
#    'files',
#    'under',
#    'svn',
#    'in',
#    'hook',
#    'scriptmanaging',
#    'svn',
#    'tags',
#    'and',
#    'trunkreintegrate',
#    'a',
#    'branch',
#    'with',
#    'externals',
#    'fails',
#    'in',
#    'svnrecursive',
#    'svn',
#    'propset']),
#  ('tortoisesvn',
#   ['how',
#    'to',
#    'svn',
#    'dump',
#    'a',
#    'specific',
#    'folder',
#    'and',
#    'load',
#    'it',
#    'into',
#    'a',
#    'specific',
#    'locationconnect',
#    'tortoisesvn',
#    'to',
#    'ubuntu',
#    'repositorytortoisesvn',
#    'sidebyside',
#    'configuration',
#    'is',
#    'incorrectbetter',
#    'merge',
#    'tool',
#    'for',
#    'subversioncan',
#    'i',
#    'have',
#    'tortoisesvn',
#    'autoadd',
#    'files?r.java',
#    'not',
#    'generatedcan',
#    'i',
#    'see',
#    'the',
#    'currently',
#    'checked',
#    'out',
#    'revision',
#    'number',
#    'in',
#    'tortoise',
#    'svn?svn',
#    'option/plugin',
#    'that',
#    "won't",
#    'allow',
#    'commit',
#    'if',
#    'files',
#    'contain',
#    'certain',
#    'stringmerge',
#    'tool',
#    'capable',
#    'of',
#    'merging',
#    'conflicting',
#    'changestortoise',
#    'svn',
#    'requires',
#    'many',
#    'tries',
#    'to',
#    'do',
#    'anything[tortoise',
#    'svn]:',
#    'the',
#    'windows',
#    'context',
#    'menu',
#    "doesn't",
#    'show',
#    'checkin',
#    'optionwhat',
#    'is',
#    'the',
#    'correct',
#    'way',
#    'to',
#    'handle',
#    'repeated',
#    'merges',
#    'of',
#    'an',
#    'svn',
#    'branch?how',
#    'to',
#    'use',
#    'svn(subversion)',
#    'with',
#    'vcs',
#    'gutter',
#    'plugin',
#    'in',
#    'sublime',
#    'text',
#    '3',
#    'on',
#    'windows',
#    '7?mysterious',
#    'nonchange',
#    'showing',
#    'up',
#    'in',
#    'tortoisesvn',
#    '/',
#    'tortoisemergesvn',
#    'overwrite',
#    'an',
#    'erntire',
#    'folder',
#    'in',
#    'repositorysubwcrev.exe',
#    'truncates',
#    'version',
#    'filessvn',
#    'operation',
#    'time',
#    'on',
#    'vista/windows',
#    '7/2008',
#    'rc2sliksvn',
#    '+',
#    'windows',
#    '2008',
#    'servereasiest',
#    'way',
#    'to',
#    'collect',
#    'revision',
#    'history',
#    'since',
#    'last',
#    'merge',
#    'in',
#    "subversioncan't",
#    'rename',
#    'project',
#    'tortoisesvn',
#    '&',
#    'subversiontortoise',
#    'svn',
#    'version',
#    '1.7.7.17493',
#    'show',
#    'log',
#    'not',
#    'workingsubclipse',
#    '(1.8.5)',
#    'requires',
#    'cleanup',
#    '/',
#    'refresh',
#    'cycle',
#    'to',
#    'detect',
#    'changes',
#    'made',
#    'with',
#    'tortoisesvn',
#    '(1.7.4)configure',
#    'svn',
#    'for',
#    'flash',
#    'action',
#    'script',
#    'programmingtortoise',
#    "won't",
#    'connect',
#    'to',
#    'subversion',
#    'server']),
#  ('r',
#   ['r',
#    'custom',
#    'parser',
#    'functionscraping',
#    'html',
#    'with',
#    'rvest',
#    'getting',
#    'http',
#    'error',
#    '416scatter',
#    'plot',
#    'that',
#    'shows',
#    'all',
#    'points',
#    'with',
#    'the',
#    'same',
#    'valueretrieving',
#    'observation',
#    'scores',
#    'for',
#    'each',
#    'principal',
#    'component',
#    'in',
#    'rhow',
#    'to',
#    'account',
#    'for',
#    'csr',
#    'and',
#    'clustering',
#    'in',
#    'uniform',
#    'spatial',
#    'data?timing',
#    'events',
#    'when',
#    'session',
#    'endsdate',
#    'transformation',
#    'in',
#    'rwhat',
#    'is',
#    'the',
#    'difference',
#    'between',
#    'a',
#    'library',
#    'and',
#    'a',
#    'package',
#    'in',
#    'r?combining',
#    'items',
#    'from',
#    'a',
#    'data.frame',
#    'list',
#    'into',
#    'a',
#    'single',
#    'data.tableimport',
#    'tcx',
#    'into',
#    'r',
#    'using',
#    'xml',
#    'packager:',
#    "what's",
#    'the',
#    'simplest',
#    'way',
#    '(oneliner?)',
#    'to',
#    'create',
#    'a',
#    'vector',
#    'of',
#    'expressions?r:',
#    'quantifying',
#    'uncertainty',
#    'for',
#    'predictions',
#    'from',
#    'lme4',
#    '(predict.mermod)r:',
#    "won't",
#    'run',
#    'code.',
#    'error',
#    'message:',
#    'cannot',
#    'establish',
#    'rsessionsplit',
#    'a',
#    'data.table',
#    'in',
#    'r',
#    'by',
#    'keyr:',
#    'update',
#    'a',
#    'column',
#    'value',
#    'by',
#    'checking',
#    'other',
#    'columns',
#    'in',
#    'the',
#    'same',
#    'rowhow',
#    'to',
#    'get',
#    'the',
#    'sum',
#    'shared',
#    'values',
#    'of',
#    'all',
#    'the',
#    'randomly',
#    'picked',
#    'two',
#    'columns',
#    'in',
#    'a',
#    'dataframeremove',
#    'all',
#    'packages',
#    'that',
#    'do',
#    'not',
#    'come',
#    'with',
#    'rpassing',
#    'function',
#    'to',
#    'multiple',
#    'columns',
#    'based',
#    'on',
#    'column',
#    'nametransform',
#    'xml',
#    'file',
#    'into',
#    'r',
#    'dataframer:',
#    'identify',
#    'duplicate',
#    'rows',
#    'and',
#    'remove',
#    'the',
#    'old',
#    'entry(by',
#    'date)very',
#    'strange',
#    'results',
#    'with',
#    'row',
#    'names.',
#    'is',
#    'this',
#    'a',
#    'bug?write',
#    'regression',
#    'summary',
#    'to',
#    'the',
#    'csv',
#    'file',
#    'in',
#    'rhow',
#    'to',
#    'compute',
#    'symbolic',
#    'derivative',
#    'of',
#    'logit',
#    'function?extracting',
#    'data',
#    'from',
#    'nested',
#    'json',
#    'document',
#    'using',
#    'tidyjson',
#    'in',
#    'rimporting',
#    'csv',
#    'files',
#    'from',
#    'a',
#    'directory',
#    'into',
#    'rinterpreting',
#    'netlogit',
#    'outputadd',
#    'line',
#    'to',
#    'plot',
#    'for',
#    "zipf's",
#    'lawreading',
#    'formatted',
#    'data',
#    'into',
#    'rr:',
#    'remove',
#    'na',
#    'from',
#    'factor',
#    'vector',
#    'and',
#    'convert',
#    'it',
#    'to',
#    'numerichow',
#    'to',
#    'read',
#    'this',
#    'type',
#    'of',
#    'data',
#    'in',
#    'rusing',
#    'gsub',
#    'in',
#    'rredundant',
#    'facet',
#    'and',
#    'axis',
#    'labels',
#    'in',
#    'ggplot2error',
#    'in',
#    'fread',
#    '(showprogress',
#    'is',
#    'not',
#    'type',
#    'integer',
#    'but',
#    'type',
#    "'logical'.",
#    'please',
#    'report.)create',
#    'a',
#    'ts',
#    'object',
#    'with',
#    'a',
#    'daily',
#    'timeseriesgeom_tile',
#    'and',
#    'geom_text',
#    'and',
#    'facet_wrap',
#    'produce',
#    'incorrect',
#    'confusion',
#    'matriceshow',
#    'to',
#    'get',
#    'latex',
#    'table',
#    'from',
#    'latex()',
#    'in',
#    'hmisc',
#    'to',
#    'align',
#    'columnsmean',
#    'and',
#    'sd',
#    'in',
#    'a',
#    'tablelibtiff',
#    'install',
#    'for',
#    'macshiny:',
#    'how',
#    'to',
#    'display',
#    'the',
#    'progress',
#    'information',
#    'from',
#    'a',
#    'timeconsuming',
#    'function',
#    'when',
#    'it',
#    "running'x'",
#    'and',
#    "'y'",
#    'lengths',
#    'differ',
#    'with',
#    'fft',
#    'in',
#    'rttest',
#    'on',
#    'multiple',
#    'boxplots',
#    'in',
#    'rprincipal',
#    'component',
#    'analysis',
#    'and',
#    'elastic',
#    'net',
#    'regressionparallel',
#    'memory',
#    'duplication/usage',
#    'in',
#    'r?progress',
#    'bar',
#    'on',
#    'macparlapply',
#    'on',
#    'sqlquery',
#    'from',
#    'rodbcvector',
#    'subsetting',
#    'vs.',
#    'list',
#    'subsettinghow',
#    'could',
#    'we',
#    'know',
#    'the',
#    'columnname',
#    '/attribute',
#    'of',
#    'items',
#    'generated',
#    'in',
#    'rules%>%',
#    'operator',
#    'r',
#    'yields',
#    'unexpected',
#    'errorfigure',
#    'space',
#    'in',
#    'eps',
#    'plotsmatching',
#    'across',
#    'two',
#    'data',
#    'frames',
#    'with',
#    'certain',
#    'observations',
#    'having',
#    'multiple',
#    'entries',
#    'to',
#    'match',
#    'againsthow',
#    'do',
#    'you',
#    'extract',
#    'date',
#    'from',
#    'the',
#    'file',
#    'name',
#    'in',
#    'r?complement',
#    'genotype',
#    'with',
#    'conditionr',
#    'data',
#    'table',
#    'group',
#    'by',
#    'with',
#    'no',
#    'j',
#    'argumentr',
#    'igraph:',
#    'color',
#    'nodes',
#    'by',
#    'degree?when',
#    '[:punct:]',
#    'is',
#    'too',
#    'muchrselenium:',
#    'select',
#    'option',
#    'from',
#    'dropdownwhy',
#    'do',
#    'i',
#    'get',
#    'different',
#    'results',
#    'using',
#    'ccf()',
#    'and',
#    'cor()',
#    'in',
#    'r?how',
#    'to',
#    'know',
#    'the',
#    'significance',
#    'of',
#    'coefficients',
#    'and',
#    'model',
#    'in',
#    'weka?randomly',
#    'selecting',
#    'from',
#    'a',
#    'subset',
#    'of',
#    'rowsrunning',
#    'r',
#    'code',
#    'remotely',
#    'from',
#    'java',
#    'applicationr',
#    'pca',
#    'using',
#    'the',
#    '7',
#    'featuresdisplaying',
#    'pvalues',
#    'instead',
#    'of',
#    'ses',
#    'in',
#    'parenthesistrouble',
#    'plotting',
#    'predict',
#    'line',
#    'in',
#    'rhow',
#    'do',
#    'i',
#    'plot',
#    'greek',
#    'letters',
#    'and',
#    'evaluated',
#    'variables',
#    'together?creating',
#    'a',
#    'data.frame',
#    'with',
#    'a',
#    'new',
#    'row',
#    'for',
#    'each',
#    'iterationvariable',
#    'as',
#    'title',
#    'in',
#    'rmarkdownis',
#    'there',
#    'a',
#    'sequencematcher',
#    'in',
#    'r?how',
#    'would',
#    'you',
#    'vectorise',
#    'this',
#    'for',
#    'loop',
#    'in',
#    'r',
#    '(s',
#    '+=',
#    'i/2)?extracting',
#    'data',
#    'sets',
#    'from',
#    'unstructured',
#    'data',
#    'in',
#    'r/',
#    'pythonhow',
#    'to',
#    'pass',
#    'fun.aggregate',
#    'as',
#    'argument',
#    'to',
#    'dcast.data.table?interpretation',
#    'of',
#    'step',
#    'size',
#    'parameter',
#    'in',
#    'deoptim',
#    'packagesharing',
#    'a',
#    'data.table',
#    'in',
#    'memory',
#    'for',
#    'parallel',
#    'computinghow',
#    'to',
#    'dynamically',
#    'add',
#    'data',
#    'to',
#    'a',
#    'dataframe?arguments',
#    'descriptions',
#    'order',
#    'in',
#    '.rd',
#    'file',
#    'when',
#    'using',
#    'the',
#    'roxygen2',
#    'tag',
#    '@inheritparamschange',
#    'title',
#    'of',
#    "geom_histogram's",
#    'legendhow',
#    'to',
#    'detect',
#    'substrings',
#    'from',
#    'multiple',
#    'lists',
#    'within',
#    'a',
#    'string',
#    'in',
#    'restimating',
#    'r2',
#    'from',
#    'a',
#    'linear',
#    'regression',
#    'manually',
#    'changing',
#    'beta',
#    'coefficientanother',
#    'way',
#    'to',
#    'access',
#    'matrix',
#    'elements',
#    'in',
#    'rr',
#    'markdown',
#    'link',
#    'is',
#    'not',
#    'formatted',
#    'blue',
#    'when',
#    'knitted',
#    'to',
#    'pdferrors',
#    'only',
#    'when',
#    'running',
#    'shiny',
#    'application',
#    'on',
#    'server',
#    'debugerror',
#    'on',
#    'choosecranmirror()',
#    'in',
#    'r',
#    '3.2.2how',
#    'can',
#    'i',
#    'compute',
#    'the',
#    'effects',
#    'in',
#    'the',
#    'same',
#    'way',
#    'as',
#    "r's",
#    'lm.fit()?what',
#    'is',
#    'the',
#    'fastest',
#    'way',
#    'to',
#    'calculate',
#    'first',
#    'two',
#    'principal',
#    'components',
#    'in',
#    'r?natural',
#    'way',
#    'to',
#    'represent',
#    'hash',
#    'tables/dictionaries/maps',
#    'in',
#    'rbinding',
#    'several',
#    'large',
#    'matrices',
#    'by',
#    'columnmulti',
#    'variables',
#    'in',
#    'the',
#    'same',
#    'plotlsf',
#    'sequential',
#    'file',
#    'name',
#    'job',
#    'submissionr',
#    'ggplot',
#    'dropping',
#    'a',
#    'factorcreating',
#    'a',
#    'heatmap',
#    'based',
#    'on',
#    'historical',
#    'map',
#    'in',
#    'rchanging',
#    'hover',
#    'in',
#    'ggplotly',
#    'facet_gridas.date',
#    'keeps',
#    'on',
#    'returning',
#    'nasexporting',
#    'multiple',
#    'glm',
#    'plots',
#    'as',
#    'pngs?ggplot2:',
#    'add',
#    'additional',
#    'guide',
#    'for',
#    'diamond',
#    'shaped',
#    'ppintscoloring',
#    'certain',
#    'sections',
#    'of',
#    'a',
#    'barplot',
#    'based',
#    'on',
#    'position',
#    'in',
#    'a',
#    'matrixhow',
#    'to',
#    'render',
#    'html',
#    'plot',
#    'in',
#    'shiny',
#    'apphow',
#    'to',
#    'get',
#    'the',
#    'ouput',
#    'of',
#    'my',
#    'result',
#    'in',
#    'json',
#    'in',
#    'rassign',
#    'value',
#    'to',
#    'r',
#    'sparsematrixr',
#    'daily',
#    'data',
#    'and',
#    'time',
#    'series',
#    'by',
#    'year',
#    'and',
#    'weekunused',
#    'arguments',
#    'in',
#    'getportfolio',
#    'when',
#    'using',
#    'rsplitting',
#    'rules',
#    'in',
#    'mvpart',
#    'vs',
#    'rpartreturn',
#    'values',
#    'from',
#    'python',
#    'script',
#    'to',
#    'r',
#    'and',
#    'storing',
#    'those',
#    'values',
#    'in',
#    '`r`request',
#    'to',
#    'improve',
#    'code',
#    'to',
#    'download',
#    'sequence',
#    'of',
#    'urlswhat',
#    'do',
#    'these',
#    'parameters',
#    'mean',
#    'in',
#    'package',
#    'h5',
#    'in',
#    'rgetting',
#    'data',
#    'out',
#    'of',
#    'raster',
#    'file',
#    'in',
#    'rhow',
#    'to',
#    'generate',
#    'classification',
#    'analysis',
#    'tables',
#    'in',
#    'r?grouped',
#    'bargraph',
#    'in',
#    'r',
#    'problems',
#    'with',
#    'y',
#    'scale',
#    'and',
#    'error',
#    'barsr',
#    'building',
#    'a',
#    'json',
#    'file',
#    'by',
#    'appending',
#    'requestsremove',
#    'lines',
#    'with',
#    'efficient',
#    'waysmallest',
#    'size',
#    'of',
#    'ggplot2',
#    'geom_text()calculation',
#    'of',
#    'anomalies',
#    'on',
#    'timeserieshow',
#    'can',
#    'i',
#    'measure',
#    'graph',
#    'statistics',
#    'at',
#    'multiple',
#    'points',
#    'in',
#    'time',
#    '(slices)',
#    'using',
#    'networkdynamic',
#    'and',
#    'tsna?get',
#    'data',
#    'from',
#    'lines()',
#    'functionplyr',
#    'along',
#    'two',
#    'dimensions',
#    '(ddply)heatmap',
#    'generation',
#    'in',
#    'rassigning',
#    'numericvector',
#    'to',
#    'a',
#    'column',
#    'of',
#    'dataframeparallelism',
#    'in',
#    'julia.',
#    'features',
#    'and',
#    'limitationscentre',
#    'title',
#    'in',
#    'pdf',
#    'converted',
#    'from',
#    'markdown',
#    'using',
#    'pandochow',
#    'to',
#    'sliderinput',
#    'for',
#    'datesr',
#    'splitting',
#    'row',
#    'in',
#    'multiple',
#    'rowsr',
#    'forecasting',
#    'package',
#    'and',
#    'daily',
#    'timeseriessubset',
#    'a',
#    'dta.frame',
#    'according',
#    'to',
#    'repeated',
#    'colnamehow',
#    'do',
#    'i',
#    'manipulate',
#    'the',
#    'grids',
#    'and',
#    'axis',
#    'with',
#    "ggplot2?i'm",
#    'coding',
#    'in',
#    'r',
#    'and',
#    'having',
#    'trouble',
#    'with',
#    'my',
#    'if',
#    'statementsis',
#    'there',
#    'a',
#    'way',
#    'to',
#    'get',
#    'tapply',
#    'to',
#    'work',
#    'with',
#    'two',
#    'index',
#    'values',
#    '(or',
#    'equivilent)?r',
#    'oce',
#    'how',
#    'to',
#    'apply',
#    'read.topo',
#    'or',
#    'as.topo',
#    'to',
#    '.xyz',
#    'file',
#    'from',
#    'etopo1how',
#    'can',
#    'i',
#    'reclaim',
#    'memory',
#    'used',
#    'by',
#    'mgcv?store',
#    'output',
#    'text',
#    'from',
#    'r',
#    'shiny',
#    'to',
#    'an',
#    'object',
#    'outside',
#    'of',
#    'the',
#    'appindexing',
#    'neigboring',
#    'values',
#    'without',
#    'loopgather',
#    'multiple',
#    'date/value',
#    'columns',
#    'using',
#    'tidyrsubset',
#    'data',
#    'using',
#    'nonsequential',
#    'row',
#    'numbersexplain',
#    'the',
#    'quantile()',
#    'function',
#    'in',
#    'rchisquare',
#    'p',
#    'value',
#    'matrix',
#    'in',
#    'roptimizing',
#    'performance',
#    'of',
#    'forloops',
#    'in',
#    "rbenford's",
#    'law',
#    'in',
#    'rmanipulating',
#    'items',
#    'of',
#    'a',
#    'vector',
#    'in',
#    'r',
#    'without',
#    'using',
#    'loopsreading',
#    'a',
#    'messy',
#    'csv',
#    'using',
#    'readlines',
#    'until',
#    'a',
#    'certain',
#    'row',
#    '/',
#    'cell',
#    'valuemodify',
#    'the',
#    'limit',
#    'of',
#    'the',
#    'y',
#    'axis',
#    'in',
#    'plot.acf',
#    '(package',
#    'nlme)how',
#    'to',
#    'visualize',
#    'pairwise',
#    'comparisons',
#    'with',
#    '`ggplot2`?readpdf',
#    '(tm',
#    'package)',
#    'in',
#    'rexpand',
#    'vector',
#    'based',
#    'on',
#    'another',
#    'vectorinterpreting',
#    'interactions',
#    'in',
#    ...]),
#  ('bigdata',
#   ['r',
#    'custom',
#    'parser',
#    'functionreturning',
#    'lots',
#    'of',
#    'items',
#    'from',
#    'a',
#    'mongodb',
#    'via',
#    'node.jsspark',
#    'shell',
#    'unable',
#    'to',
#    'read',
#    'file',
#    'at',
#    'valid',
#    'pathbinding',
#    'several',
#    'large',
#    'matrices',
#    'by',
#    'columnanalyzing',
#    '115000',
#    'strings',
#    'pasted',
#    'to',
#    'consolecount',
#    'number',
#    'of',
#    'records',
#    'in',
#    'a',
#    'column',
#    'family',
#    'in',
#    'an',
#    'hbase',
#    'tableusing',
#    'elasticsearch',
#    'with',
#    'hadoop',
#    'map',
#    'reduceerror',
#    'with',
#    'make',
#    'apps',
#    'of',
#    'huecode',
#    'or',
#    'algo',
#    'for',
#    'modulo',
#    'divisionhow',
#    'reexecution',
#    'would',
#    'be',
#    'the',
#    'primary',
#    'source',
#    'of',
#    'fault',
#    'tolerance?'])]

# %%
# step5: remove the stopwords using the nltk package
step5 = step4.map(lambda w: ((w[0],[word for word in w[1] if word not in stopwords.words('english')])))
step5.take(5)
# Out:
# [('php',
#   ['use',
#    'variable',
#    'storing',
#    'equal',
#    'sign',
#    'sql',
#    'querysplit',
#    'sentence',
#    'character',
#    'limited',
#    'arraysfile_get_contents',
#    'failure',
#    'windowsmysql',
#    'selecting',
#    'random',
#    'rows',
#    'one',
#    'unique',
#    'row',
#    'within',
#    'one',
#    'querysoap',
#    'ntlm',
#    'authentication',
#    'debian',
#    'iis',
#    'serverphp',
#    'file',
#    'renamephp:',
#    'possible',
#    'retrieve',
#    'class',
#    'name',
#    'child',
#    'class?greek',
#    'character',
#    'insertion',
#    'php',
#    'compared',
#    'sql',
#    'server',
#    'management',
#    'studiocheck',
#    'malicious',
#    'xml',
#    'allowing',
#    'dtd',
#    'loading?mysql',
#    'data',
#    'query',
#    'refreshingreplacing',
#    'wordpress',
#    'footer',
#    'custom',
#    'html',
#    'onemysql',
#    'results',
#    'getting',
#    'repeated',
#    'comparing',
#    'results',
#    'loopphp',
#    'mysql',
#    'login',
#    'header',
#    'issue$stmt',
#    '=',
#    '$conn>prepare($sql)',
#    'returns',
#    'undefined',
#    '$stmt',
#    'var',
#    '(solved)woocommerce',
#    'custom',
#    'shop',
#    'page',
#    '(archiveproduct.php)',
#    'search',
#    'results',
#    'pagehow',
#    'bootstrap',
#    'modal',
#    'get',
#    "'id'",
#    'urllinux',
#    'php',
#    'extractto',
#    'returns',
#    'whole',
#    'path',
#    'instead',
#    'file',
#    'structuredoes',
#    "abraham's",
#    'twitteroauth',
#    'library',
#    'work',
#    'update_with_media?php',
#    'pdo',
#    'mysql',
#    'execute();laravel',
#    'config::get()',
#    'particular',
#    'environment',
#    '(not',
#    'current)how',
#    'would',
#    'implement',
#    'form',
#    'based',
#    'authentication',
#    'without',
#    'backing',
#    'database?how',
#    'import',
#    'file',
#    'contents',
#    'nodeimage',
#    'ajax',
#    'search',
#    'working',
#    'safarisending',
#    'high',
#    'low',
#    'price',
#    'limit',
#    'linkprotect',
#    'login',
#    'https',
#    'availabletrack',
#    'changes',
#    'mysql',
#    'table',
#    'using',
#    'node.js"""',
#    "'",
#    '""',
#    'converted',
#    '""',
#    '&#8216;',
#    '"""multiple',
#    'order',
#    'statement',
#    'mysqlfile_get_contents',
#    'url',
#    'longphp',
#    'return_var',
#    'codes?need',
#    'way',
#    'check',
#    'see',
#    'wildcard',
#    'string',
#    'matches',
#    'given',
#    'string',
#    'phpinsert',
#    'record',
#    'image',
#    'php',
#    'jqueryauto',
#    'complete',
#    'fields',
#    'previous',
#    'valuesurl',
#    'rewrite:',
#    'multiple',
#    'addresses',
#    'per',
#    'articlecreate',
#    'multipal',
#    'website',
#    'magentoselecting',
#    'text',
#    'datagrid',
#    'copying',
#    'message',
#    'box',
#    'php',
#    'pagephp',
#    'mysql',
#    'data',
#    'base',
#    'retrieval',
#    'three',
#    'records',
#    'one',
#    'rowsonata',
#    'admin',
#    'symfony2',
#    'performancereturning',
#    'random',
#    'value',
#    'array',
#    'probability',
#    'proportional',
#    "it's",
#    'valuetroubles',
#    'splitting',
#    'stringpassing',
#    'capture',
#    'url',
#    'variables',
#    'jquery',
#    'without',
#    'phpzend',
#    'framework',
#    '2.3',
#    'translate',
#    'formcalculate',
#    'dynamic',
#    'values',
#    'rate',
#    '*',
#    'quantityvalidate',
#    'uk',
#    'short',
#    'postcodeget',
#    'array',
#    'elements',
#    'dynamically',
#    'based',
#    'checkbox',
#    'checked?how',
#    'load',
#    'mysql',
#    'data',
#    'separate',
#    'formsphp',
#    'function',
#    'reaching',
#    'innermost',
#    'nested',
#    'blocklaravel',
#    '3:',
#    'difficulty',
#    'getting',
#    'head',
#    'wrapped',
#    'around',
#    '`has_one()`',
#    'relationshipini_set',
#    'include_path',
#    'workinginvalid',
#    'argument',
#    'supplied',
#    'foreach;',
#    'pdosimple',
#    'comment',
#    'box',
#    'php',
#    'mysql',
#    "didn't",
#    'workdeprecated',
#    'php',
#    '$http_post_fileshow',
#    'retrieve',
#    'one',
#    'row/one',
#    'field',
#    'using',
#    'php',
#    'mysql_fetch_arrayhow',
#    'call',
#    'methods',
#    'php',
#    'xmlwhere',
#    'php',
#    'file()',
#    'function',
#    'get',
#    'line',
#    'numbers?how',
#    'enable',
#    'utf',
#    '8',
#    'support',
#    'pcre',
#    'xampp',
#    'windows?html',
#    'link',
#    'tr',
#    'broken',
#    'placehow',
#    'get',
#    'dropdown',
#    'selected',
#    'value',
#    'pass',
#    'mysql',
#    'query?how',
#    'achive',
#    'scenario:',
#    'paypal',
#    'recurring',
#    '+',
#    'trial',
#    'period',
#    '+',
#    'base',
#    'priceusing',
#    'alternative',
#    'sidebar',
#    'creating',
#    'wordpress',
#    'themeplupload:',
#    'get',
#    'data',
#    'attributes',
#    'multiple',
#    'dynamic',
#    'dropzoneswordpress',
#    'page',
#    'working',
#    'changing',
#    'hostingsimple',
#    'html',
#    'dom',
#    'space',
#    'classuser',
#    'rights',
#    'cmsyii',
#    'ajax',
#    'form',
#    'submition',
#    'without',
#    'inline',
#    'script$this>forward',
#    'looses',
#    "user's",
#    'requested',
#    'route?cakephp',
#    'misterious',
#    'automatic',
#    'validation',
#    'rule',
#    'fieldmysql',
#    'select',
#    'content',
#    'multiple',
#    'languagesdealing',
#    'php',
#    'server',
#    'mysql',
#    'server',
#    'different',
#    'time',
#    'zoneshow',
#    'use',
#    'insecure',
#    'web',
#    'script',
#    'ssl',
#    'pagesimage',
#    'storing',
#    'mysql',
#    'database',
#    'via',
#    'phpphpunit',
#    'code',
#    'coverage',
#    'interfaces',
#    'shows',
#    'successpdo',
#    'object',
#    'rows',
#    'printing',
#    'twicefrom',
#    'address',
#    'come',
#    'server',
#    'extension',
#    'mailmysqii',
#    'select',
#    'count',
#    'order',
#    'countsending',
#    'mail',
#    'using',
#    'php',
#    'pear',
#    'windowsphp/mysql',
#    'queries',
#    'vs',
#    'arrays?php/ajax',
#    'advice',
#    'replacing',
#    'iframe',
#    'div',
#    '(combined',
#    'ajax)jquery',
#    'table',
#    'pagination',
#    '(mysql',
#    '+',
#    'php)uploading',
#    'pdf',
#    'files',
#    'php',
#    '5.4',
#    'kcfindervalidating',
#    'html',
#    'dropdown',
#    'menu',
#    'javascript?query',
#    'syntax',
#    'php',
#    'variables',
#    'select',
#    'two',
#    'mysql',
#    'tableshow',
#    'return',
#    'class',
#    'element?jquery',
#    'datatables',
#    'â€“',
#    'click',
#    'event',
#    'handler',
#    'working',
#    '2nd',
#    'page',
#    'paginationbrowser',
#    'back',
#    'button',
#    'silex',
#    "applicationcan't",
#    'access',
#    'variables',
#    '_bootstrap.php',
#    'codeceptionlimit',
#    'submitting',
#    'many',
#    'requests',
#    'ajax',
#    'php',
#    'formphp',
#    'array',
#    'values',
#    'distribution',
#    'near',
#    'averageconvert',
#    'rgb',
#    'html',
#    'named',
#    'colors',
#    'phphow',
#    'insert',
#    'retrieve',
#    'images',
#    'database',
#    'using',
#    'phpphp',
#    'converting',
#    'date',
#    'timestamp',
#    'using',
#    'datetime',
#    'decreases',
#    '1',
#    'day',
#    'weirdis_file()',
#    'local',
#    'file',
#    'inclusion',
#    'vulnerabilityphp',
#    'return',
#    'value',
#    'recursive',
#    'functionhow',
#    'merge',
#    '3',
#    'csv',
#    'files',
#    '1',
#    'csv',
#    'file',
#    'using',
#    'php?"how',
#    'display',
#    '""12',
#    'minutes',
#    'ago""',
#    'etc',
#    'php',
#    'webpage?"batch',
#    'code',
#    'indenters',
#    'beautifiershaving',
#    'issue',
#    'getting',
#    'custom',
#    'console',
#    'commands',
#    'work',
#    'yii2',
#    'whilst',
#    'running',
#    'multiple',
#    'applicationsajax',
#    'check',
#    'registered',
#    'email',
#    'formphp',
#    'script',
#    'populate',
#    'mysql',
#    'tables"web',
#    'database',
#    'server',
#    'settings',
#    'get',
#    'utc',
#    'timezone',
#    '""right"""php',
#    'multithreadinghow',
#    'compare',
#    'strings',
#    'without',
#    'using',
#    'mysql',
#    'queries?looping',
#    'tables',
#    'search',
#    'button',
#    'presshow',
#    'add',
#    'email',
#    'function',
#    'php',
#    'checking',
#    'script?logging',
#    'user',
#    'completely',
#    'websitechange',
#    'relative',
#    'url',
#    'curlphp',
#    'class',
#    'works',
#    'chrome',
#    'firefoxajax',
#    'returning',
#    'result',
#    'phperror',
#    'uploading',
#    'large',
#    'file',
#    '(php)i',
#    'want',
#    'clear',
#    'contents',
#    'file',
#    'chrome',
#    'extension',
#    'file',
#    'server.',
#    'that?using',
#    'eval()',
#    'protecting',
#    'phpphp',
#    'check',
#    'location',
#    'email',
#    'sent',
#    'well',
#    'email',
#    'bouncedundefined',
#    'variable:',
#    'con',
#    'c:\\wamp\\www\\android_connect\\db_connect.php',
#    'line',
#    '<i>48</i>check',
#    'file',
#    'permissionsintroducing',
#    'pythonfast(er)',
#    'way',
#    'get',
#    'file',
#    'inode',
#    'using',
#    'phpregex',
#    'breadcrumb',
#    'phpjquery',
#    'ui',
#    'changing',
#    'source',
#    'mysql',
#    'datagoto',
#    'command',
#    'php?tools',
#    'php',
#    'code',
#    'refactoringphpmyadmin:',
#    'automatically',
#    'open',
#    'specific',
#    'table',
#    'logged',
#    'inallow',
#    'users',
#    'plot',
#    'points',
#    'google',
#    'map',
#    '(with',
#    'php/ajax)cakephp',
#    'exceptionsmarty',
#    'url',
#    'containshow',
#    'write',
#    'session',
#    'www.',
#    'nonwww',
#    'version',
#    'domain?mysql',
#    'query',
#    'values',
#    'arrayhow',
#    'automatically',
#    'bring',
#    'forward',
#    'january',
#    'marks',
#    'february',
#    'marks',
#    'field',
#    'month',
#    'january',
#    'ends?"i\'m',
#    'getting',
#    'data',
#    '$_files[""file""][""type""]',
#    '$_files[""file""][""size""]',
#    'even',
#    'though',
#    '$_files[""file""][""name""]',
#    'retuning',
#    'filename"ask',
#    'different',
#    'badges',
#    'product',
#    'shopify?difference',
#    '2',
#    'timestamps',
#    'days',
#    'mysql',
#    'table',
#    'user',
#    'session',
#    'loginsending',
#    'put',
#    'command',
#    'curl',
#    'phpwhere',
#    'visual',
#    'composer',
#    'store',
#    'links?why',
#    'safari/webkit',
#    'appends',
#    '.html',
#    'downloaded',
#    'files?doctrine',
#    'register',
#    'custom',
#    'dql',
#    'functionsmultiple',
#    'dropdowns',
#    'populated',
#    'one',
#    'related',
#    'table',
#    'cakephp',
#    '3php',
#    'error',
#    'class',
#    "'google_http_request'",
#    'foundcss',
#    'external',
#    'url',
#    'read',
#    'site',
#    'font',
#    'definitions',
#    'accesseduse',
#    'dynamically',
#    'created',
#    'form',
#    'values',
#    'set',
#    'variables',
#    'post',
#    'requests',
#    'phpupload',
#    'avi',
#    'php',
#    'errorsphp',
#    'random',
#    'set',
#    'imagesserialize()',
#    '$_session"how',
#    'loop',
#    'database',
#    'table',
#    'select',
#    'everything',
#    '""type"".',
#    'using',
#    'php',
#    'sql"php',
#    'multiple',
#    'classes',
#    'methods',
#    'nameadd',
#    'cart',
#    'php',
#    'session',
#    'get',
#    'methodshow',
#    'images',
#    'array',
#    'smartyusing',
#    'php',
#    'regex',
#    'get',
#    'value',
#    'javascript',
#    'filehow',
#    'countermeasure',
#    'image',
#    'hotlinking',
#    'protection',
#    'curl?',
#    'need',
#    'download',
#    'imagesanchor',
#    'helper',
#    'zend',
#    'framework',
#    '2how',
#    'change',
#    'default',
#    'date',
#    'format',
#    'oracle',
#    'db',
#    'trunc?how',
#    'get',
#    'rid',
#    'spam',
#    'mysql',
#    'insert?mysql/php',
#    'retrieve/check',
#    'message',
#    'new',
#    'userdoctrine',
#    '2',
#    'order',
#    'count',
#    'join',
#    'symfony',
#    '2',
#    'pagerfantahow',
#    'dynamicly',
#    'set',
#    'array',
#    'variable?ajax',
#    'loading',
#    'complex',
#    'projectsdynamically',
#    'create',
#    'content',
#    'table',
#    'phpphp',
#    'json_encode',
#    'extra',
#    'quote',
#    'array',
#    'square',
#    'bracketgetting',
#    'filename',
#    'without',
#    'extension',
#    'phpunknown',
#    'sql',
#    'syntax',
#    'errorusing',
#    'variable',
#    'inside',
#    'array',
#    'accessornginx',
#    'rewrite',
#    'file',
#    'exists',
#    '/',
#    'pattern',
#    'matchedstart',
#    'seleniumserver',
#    'jenkins',
#    'build',
#    'stepphp',
#    "$_get['word']",
#    'working',
#    'word',
#    'string',
#    'starting',
#    "'#'",
#    'characterreturning',
#    'php',
#    'associative',
#    'array',
#    'function',
#    'ajax',
#    'call',
#    'json_encode()',
#    'objectphp',
#    'beginner:',
#    'display',
#    "user's",
#    'answers',
#    'another',
#    'php',
#    'file?not',
#    'retrieving',
#    'rows',
#    'db',
#    'joining',
#    'tableshow',
#    'log',
#    'uncaught',
#    'exceptions',
#    'php?php',
#    'preg_replace',
#    'working',
#    'like',
#    'expectedwrite',
#    'arabic',
#    'language',
#    'text',
#    'boxregex',
#    'replace',
#    'character',
#    'either',
#    'bothphp',
#    'sql',
#    'server',
#    '2005+sql',
#    'server',
#    'vs',
#    'mysql',
#    'php',
#    'vs',
#    'coldfusionsegmentation',
#    'fault',
#    'running',
#    'gearman',
#    'php',
#    'command',
#    'linecreating',
#    'short',
#    'url',
#    'multiple',
#    'controller?mongo',
#    '+',
#    'php:',
#    'updating',
#    'documents',
#    'collection',
#    'new',
#    'arrayphp',
#    'increment',
#    'recursive',
#    'functionis',
#    'possible',
#    'join',
#    'two',
#    'query',
#    'result',
#    'php',
#    'code?stdclass',
#    'vs',
#    'array.',
#    'recommended?php',
#    'datetime:',
#    'get',
#    'differnce',
#    'datetime',
#    'object',
#    'current',
#    'timewhat',
#    'point',
#    'interfaces',
#    'php?best',
#    'approach',
#    'parse',
#    'sql',
#    'php',
#    'files?calling',
#    '(404)',
#    'inexisting',
#    'page',
#    'vs',
#    'blank',
#    'page.',
#    'one',
#    'consumes',
#    'less',
#    'resources?how',
#    'remove',
#    'spaces',
#    'array?can',
#    'use',
#    'html',
#    'upload',
#    'text',
#    'input',
#    'file?while',
#    'retreving',
#    'data',
#    'using',
#    'ajax',
#    'getting',
#    'error',
#    'messagemoodle:',
#    'sql',
#    'clause',
#    'stdclass',
#    'objectwhat',
#    'maximum',
#    'file',
#    'upload',
#    'size',
#    'php',
#    'ini',
#    'filemysql',
#    'ordering',
#    'desc',
#    'random?getting',
#    'error',
#    'message',
#    'try',
#    'take',
#    'values',
#    'array',
#    'insert',
#    'mysqlhow',
#    'create',
#    'wordpress',
#    'loop',
#    'categorywhy',
#    "isn't",
#    'clause',
#    'accepting',
#    'variable?',
#    'laravel',
#    '5.3failed',
#    'open',
#    'stream',
#    'saving',
#    'image.',
#    'hostingerwhen',
#    'update',
#    'database',
#    "don't",
#    'want',
#    'update',
#    "columns$_session's",
#    'retrievedmulti',
#    'language',
#    'codeigniterhow',
#    'login',
#    'curl',
#    'post',
#    'cookiecompile',
#    'php',
#    'script',
#    'linuxsplit',
#    'tags',
#    'javascript',
#    'languageiis',
#    '8.5',
#    '500',
#    'internal',
#    'server',
#    'errorinsert',
#    'get',
#    'response',
#    'array',
#    'objectssubmit',
#    'button',
#    'downloading',
#    'php',
#    'instead',
#    'running',
#    'itbootstrap',
#    'form',
#    'validation',
#    'submit',
#    ...]),
#  ('svn',
#   ['svn',
#    'dump',
#    'specific',
#    'folder',
#    'load',
#    'specific',
#    'locationsetting',
#    '&',
#    'finding',
#    'svn',
#    'repository',
#    'system',
#    'lanankhsvn',
#    'cannot',
#    'connect',
#    'due',
#    'proxyhow',
#    'find',
#    'file',
#    'subversion',
#    'repository',
#    'history?repository',
#    'layout',
#    'large',
#    'maven',
#    'projectsscript',
#    'backup',
#    'svn',
#    'repository',
#    'network',
#    'sharelimit',
#    'user',
#    'access',
#    'repositories',
#    'assembla',
#    'another',
#    'svn',
#    'hosting',
#    'servicehow',
#    'implement',
#    'precommit',
#    'hook',
#    'script',
#    'svn',
#    'calls',
#    'dos2unix',
#    'validate',
#    'checkedin',
#    'fileis',
#    'way',
#    'get',
#    "'recent",
#    "messages'",
#    'commiting',
#    'using',
#    'svn',
#    'command',
#    'line',
#    'windowswhat',
#    'good',
#    'repository',
#    'layout',
#    'releases',
#    'projects',
#    'subversion?how',
#    'export',
#    '(and',
#    'import)',
#    'subversion',
#    'repository?using',
#    'wiki',
#    'central',
#    'development',
#    'project',
#    'repositorysource',
#    'control',
#    'everyone?better',
#    'merge',
#    'tool',
#    'subversioncan',
#    'tortoisesvn',
#    'autoadd',
#    'files?can',
#    'partial',
#    'checkout',
#    'subversion?running',
#    'command',
#    'cmd',
#    'background',
#    'windows',
#    'form',
#    'applicationmove',
#    'mixture',
#    'versioned',
#    'unversioned',
#    'files',
#    'foldersrecommendations',
#    'regarding',
#    'continuous',
#    'integration',
#    'systemsignore',
#    'svn',
#    'ignore...',
#    'possible?is',
#    'version',
#    'control',
#    'necessary',
#    'small',
#    'development',
#    'group',
#    '(12',
#    'programmers)?mirroring',
#    'perforce',
#    'svk?changing',
#    'directory',
#    'structure',
#    'subversionhow',
#    'implement',
#    'post',
#    'commit',
#    'hook',
#    'trac',
#    '&',
#    'svn',
#    'windows',
#    'environment?using',
#    'actionbarsherlock',
#    'subversionbest',
#    'way',
#    'set',
#    'cruisecontrol',
#    'iis',
#    '5.1',
#    'dev',
#    'box',
#    'iis6',
#    'serverbest',
#    'general',
#    'svn',
#    'ignore',
#    'pattern?adding',
#    'svn',
#    'repository',
#    'eclipseuse',
#    'current',
#    'subversion',
#    'slave',
#    'server',
#    'master',
#    'serverhow',
#    'ignore',
#    'files',
#    'subversion?good',
#    'linux',
#    '(ubuntu)',
#    'svn',
#    'clientcan',
#    'specify',
#    'filenames',
#    'using',
#    'wildcards',
#    'regexes',
#    'subversion',
#    'mv',
#    'command?what',
#    'preferred',
#    'method',
#    'moving',
#    'directory',
#    'structures',
#    'around',
#    'subversion?svn',
#    'checkout',
#    'questionhow',
#    'overcome',
#    'svn',
#    "'out",
#    "date'",
#    'error?can',
#    'merge',
#    'two',
#    'microsoft',
#    'word',
#    'documents',
#    'reliably',
#    'subversion?can',
#    'see',
#    'currently',
#    'checked',
#    'revision',
#    'number',
#    'tortoise',
#    'svn?why',
#    'mvn',
#    'release:prepare',
#    'fail',
#    'tagging?clean',
#    'builds',
#    'continuous',
#    'integrationhow',
#    'use',
#    'textmate',
#    'command',
#    'line',
#    'subversion',
#    'message',
#    'editor?how',
#    'ensure',
#    'mvn',
#    'release',
#    'plugin',
#    "won't",
#    'build',
#    'uncommitted',
#    'changes',
#    'custom',
#    'packaging',
#    "typewhat's",
#    'difference',
#    'subclipse',
#    'get',
#    'contents',
#    'get',
#    'revision?moving',
#    'vss',
#    'svnssh',
#    'access',
#    'ubuntu',
#    'box',
#    'terminalhow',
#    'switch',
#    'back',
#    'previous',
#    'version',
#    'file',
#    'without',
#    'deleting',
#    'subsequent',
#    'revisions?svn:',
#    'module',
#    'organization',
#    'early',
#    'development',
#    'processsvn',
#    'option/plugin',
#    "won't",
#    'allow',
#    'commit',
#    'files',
#    'contain',
#    'certain',
#    'stringmerging',
#    "users'",
#    'history',
#    'svn<rctbridgemodule.h>',
#    "can't",
#    'found',
#    'ios',
#    'buildhow',
#    'recover',
#    'repository',
#    'using',
#    'svn',
#    'hotcopy?avoiding',
#    'svn',
#    'recursive',
#    'checkout',
#    'externalsable',
#    'delete',
#    'specific',
#    'revision',
#    'svn?"how',
#    'fix',
#    'svn',
#    'commit',
#    'fails',
#    '""out',
#    'date""?"tortoise',
#    'svn',
#    'requires',
#    'many',
#    'tries',
#    'anythingsvn',
#    'client',
#    'checkout',
#    'errorsregex',
#    'determine',
#    'branch',
#    'svn',
#    'repository',
#    'urlwhat',
#    'correct',
#    'way',
#    'handle',
#    'repeated',
#    'merges',
#    'svn',
#    'branch?how',
#    'use',
#    'find',
#    'recursively',
#    'backup',
#    'multiple',
#    'subversion',
#    'repositorieshow',
#    'use',
#    'svn(subversion)',
#    'vcs',
#    'gutter',
#    'plugin',
#    'sublime',
#    'text',
#    '3',
#    'windows',
#    '7?identical',
#    'consecutive',
#    'commit',
#    'messages',
#    'userdisplay',
#    'folder',
#    'visual',
#    'studioscript',
#    'add',
#    'files',
#    'svn',
#    'filterstrac',
#    'svnauthzadminplugin',
#    'install',
#    'erroris',
#    'equivalent',
#    'flashbake',
#    '(easy',
#    'version',
#    'control)',
#    'perforce',
#    'subversionsvn',
#    'log',
#    'missing',
#    'revisionscan',
#    'combine',
#    'revisions',
#    'subversionbest',
#    'way',
#    'manage',
#    'multiple',
#    'apps',
#    'subversionhow',
#    'find',
#    'file',
#    'ever',
#    'existed',
#    'svnrepo?how',
#    'setup',
#    'svn',
#    'general',
#    'website',
#    'development/deployment?mysterious',
#    'nonchange',
#    'showing',
#    'tortoisesvn',
#    '/',
#    'tortoisemergeworking',
#    'large',
#    'size',
#    'branches',
#    'svnhow',
#    'allow',
#    'users',
#    'run',
#    'website',
#    'without',
#    'adding',
#    'bin',
#    'folder',
#    'svn?python',
#    '+',
#    'svn',
#    '+',
#    'windows/mac',
#    '=',
#    'invalid',
#    'syntax?how',
#    'revert',
#    'one',
#    'commit',
#    'reintegrated',
#    'branch?eclipse',
#    'project',
#    'management',
#    'svnxcode',
#    'svn',
#    'client',
#    'certificateshow',
#    'check',
#    'subversion',
#    'repository',
#    'network',
#    'share?"xcode',
#    '4.3',
#    '>',
#    'svn',
#    'issue',
#    '""project',
#    'default',
#    'build',
#    'configuration"""svn',
#    "won't",
#    'let',
#    'commit',
#    'moved',
#    'tree',
#    'one',
#    'filegoogle',
#    'code',
#    'email',
#    'notificationsvn',
#    'copy',
#    'problem',
#    'directoriesinstalling',
#    'trac',
#    'subversion',
#    '1.6"svn',
#    'subversion',
#    'exception',
#    '""svn:',
#    'options',
#    "'https://www.mymachine.com/svn/",
#    "':",
#    'could',
#    'connect',
#    'server',
#    '(https://www.mymachine.com',
#    ')"""determine',
#    'total',
#    'size',
#    'svn',
#    'directory/trunksubclipse',
#    'checkout',
#    'svn',
#    'repository',
#    'nonroot',
#    'folderlearning',
#    'svn',
#    'simple',
#    'beginner',
#    'questionshow',
#    'make',
#    'svn',
#    'diff',
#    'show',
#    'nonwhitespace',
#    'line',
#    'changes',
#    'two',
#    'revisionshow',
#    'get',
#    'current',
#    'user',
#    'logged',
#    'apache',
#    'realm?using',
#    'cruisecontrol.net',
#    'svn',
#    'suddenly',
#    'getting',
#    'access',
#    'path',
#    'denied',
#    'build',
#    'processsubversion:',
#    'batching',
#    'createdirectory',
#    'changes',
#    'single',
#    'commitsafely',
#    'move',
#    'svn',
#    'folders',
#    'filescreated',
#    '/',
#    'modified',
#    'date',
#    "doesn't",
#    'change',
#    'copy',
#    'overwrite',
#    'destination',
#    'file',
#    'windowssvn',
#    ':',
#    'export',
#    'modified',
#    'files',
#    'revisions',
#    'committed',
#    'specific',
#    'commentsvn',
#    'operation',
#    'time',
#    'vista/windows',
#    '7/2008',
#    'rc2wrong',
#    'tag',
#    'maven',
#    'release',
#    'plugin',
#    'multi',
#    'module',
#    'projectsliksvn',
#    '+',
#    'windows',
#    '2008',
#    'servereasiest',
#    'way',
#    'collect',
#    'revision',
#    'history',
#    'since',
#    'last',
#    'merge',
#    "subversioncan't",
#    'rename',
#    'project',
#    'tortoisesvn',
#    '&',
#    'subversionhow',
#    'checout',
#    'ip?',
#    'svnhooking',
#    'svn',
#    'asp.net',
#    'web',
#    'applicationhow',
#    'use',
#    'downloadsvn',
#    'fatortoise',
#    'svn',
#    'version',
#    '1.7.7.17493',
#    'show',
#    'log',
#    'workingfind',
#    'checked',
#    'files',
#    'users',
#    'svnssis',
#    'version',
#    'controlling',
#    '+',
#    'subversionissues',
#    'merging',
#    'brancheseclipse',
#    'plugin',
#    'copy',
#    'names',
#    'committed',
#    'classesconfigure',
#    'svn',
#    'flash',
#    'action',
#    'script',
#    'programmingwhat',
#    '(xcode)',
#    'svn',
#    'repository',
#    'use',
#    'itunable',
#    'start',
#    'subversion',
#    'windows',
#    '2003',
#    'server.',
#    'startservice',
#    'failed',
#    '1053cvs2svn',
#    'one',
#    'revisionhow',
#    'write',
#    'wrapper',
#    'script',
#    'create',
#    'svn',
#    'branch?reintegrate',
#    'branch',
#    'vs',
#    'merge',
#    'range',
#    'revision"svn',
#    'copy',
#    'returns',
#    '""repository',
#    'moved',
#    'permanetly"""svn',
#    'merge',
#    '2',
#    'branch',
#    'created',
#    'different',
#    'sourcegetting',
#    'django',
#    'subversion',
#    'work',
#    'together',
#    'dreamhostssis',
#    'packages',
#    'version',
#    'controllingdeploying',
#    'appharbor',
#    'using',
#    'subversiontortoise',
#    "won't",
#    'connect',
#    'subversion',
#    'servertrac',
#    'task',
#    'context',
#    'sharing',
#    'mylynfailed',
#    'importing',
#    'code',
#    'svn',
#    'git',
#    'svn',
#    'trunk',
#    'emptymultiple',
#    'svn',
#    'repositories',
#    'single',
#    'company',
#    'repositoryconfiguring',
#    'multiple',
#    'build',
#    'configurations',
#    'shared',
#    'vcs',
#    'root',
#    'teamcityversion',
#    'control',
#    'file',
#    'level',
#    'controlwhich',
#    'vcs',
#    'use',
#    'google',
#    'code?import',
#    'separate',
#    'svn',
#    'directories',
#    'git',
#    'branchesmodify',
#    'files',
#    'svn',
#    'hook',
#    'scriptmanaging',
#    'svn',
#    'tags',
#    'trunkreintegrate',
#    'branch',
#    'externals',
#    'fails',
#    'svnrecursive',
#    'svn',
#    'propset']),
#  ('tortoisesvn',
#   ['svn',
#    'dump',
#    'specific',
#    'folder',
#    'load',
#    'specific',
#    'locationconnect',
#    'tortoisesvn',
#    'ubuntu',
#    'repositorytortoisesvn',
#    'sidebyside',
#    'configuration',
#    'incorrectbetter',
#    'merge',
#    'tool',
#    'subversioncan',
#    'tortoisesvn',
#    'autoadd',
#    'files?r.java',
#    'generatedcan',
#    'see',
#    'currently',
#    'checked',
#    'revision',
#    'number',
#    'tortoise',
#    'svn?svn',
#    'option/plugin',
#    "won't",
#    'allow',
#    'commit',
#    'files',
#    'contain',
#    'certain',
#    'stringmerge',
#    'tool',
#    'capable',
#    'merging',
#    'conflicting',
#    'changestortoise',
#    'svn',
#    'requires',
#    'many',
#    'tries',
#    'anything[tortoise',
#    'svn]:',
#    'windows',
#    'context',
#    'menu',
#    "doesn't",
#    'show',
#    'checkin',
#    'optionwhat',
#    'correct',
#    'way',
#    'handle',
#    'repeated',
#    'merges',
#    'svn',
#    'branch?how',
#    'use',
#    'svn(subversion)',
#    'vcs',
#    'gutter',
#    'plugin',
#    'sublime',
#    'text',
#    '3',
#    'windows',
#    '7?mysterious',
#    'nonchange',
#    'showing',
#    'tortoisesvn',
#    '/',
#    'tortoisemergesvn',
#    'overwrite',
#    'erntire',
#    'folder',
#    'repositorysubwcrev.exe',
#    'truncates',
#    'version',
#    'filessvn',
#    'operation',
#    'time',
#    'vista/windows',
#    '7/2008',
#    'rc2sliksvn',
#    '+',
#    'windows',
#    '2008',
#    'servereasiest',
#    'way',
#    'collect',
#    'revision',
#    'history',
#    'since',
#    'last',
#    'merge',
#    "subversioncan't",
#    'rename',
#    'project',
#    'tortoisesvn',
#    '&',
#    'subversiontortoise',
#    'svn',
#    'version',
#    '1.7.7.17493',
#    'show',
#    'log',
#    'workingsubclipse',
#    '(1.8.5)',
#    'requires',
#    'cleanup',
#    '/',
#    'refresh',
#    'cycle',
#    'detect',
#    'changes',
#    'made',
#    'tortoisesvn',
#    '(1.7.4)configure',
#    'svn',
#    'flash',
#    'action',
#    'script',
#    'programmingtortoise',
#    "won't",
#    'connect',
#    'subversion',
#    'server']),
#  ('r',
#   ['r',
#    'custom',
#    'parser',
#    'functionscraping',
#    'html',
#    'rvest',
#    'getting',
#    'http',
#    'error',
#    '416scatter',
#    'plot',
#    'shows',
#    'points',
#    'valueretrieving',
#    'observation',
#    'scores',
#    'principal',
#    'component',
#    'rhow',
#    'account',
#    'csr',
#    'clustering',
#    'uniform',
#    'spatial',
#    'data?timing',
#    'events',
#    'session',
#    'endsdate',
#    'transformation',
#    'rwhat',
#    'difference',
#    'library',
#    'package',
#    'r?combining',
#    'items',
#    'data.frame',
#    'list',
#    'single',
#    'data.tableimport',
#    'tcx',
#    'r',
#    'using',
#    'xml',
#    'packager:',
#    "what's",
#    'simplest',
#    'way',
#    '(oneliner?)',
#    'create',
#    'vector',
#    'expressions?r:',
#    'quantifying',
#    'uncertainty',
#    'predictions',
#    'lme4',
#    '(predict.mermod)r:',
#    "won't",
#    'run',
#    'code.',
#    'error',
#    'message:',
#    'cannot',
#    'establish',
#    'rsessionsplit',
#    'data.table',
#    'r',
#    'keyr:',
#    'update',
#    'column',
#    'value',
#    'checking',
#    'columns',
#    'rowhow',
#    'get',
#    'sum',
#    'shared',
#    'values',
#    'randomly',
#    'picked',
#    'two',
#    'columns',
#    'dataframeremove',
#    'packages',
#    'come',
#    'rpassing',
#    'function',
#    'multiple',
#    'columns',
#    'based',
#    'column',
#    'nametransform',
#    'xml',
#    'file',
#    'r',
#    'dataframer:',
#    'identify',
#    'duplicate',
#    'rows',
#    'remove',
#    'old',
#    'entry(by',
#    'date)very',
#    'strange',
#    'results',
#    'row',
#    'names.',
#    'bug?write',
#    'regression',
#    'summary',
#    'csv',
#    'file',
#    'rhow',
#    'compute',
#    'symbolic',
#    'derivative',
#    'logit',
#    'function?extracting',
#    'data',
#    'nested',
#    'json',
#    'document',
#    'using',
#    'tidyjson',
#    'rimporting',
#    'csv',
#    'files',
#    'directory',
#    'rinterpreting',
#    'netlogit',
#    'outputadd',
#    'line',
#    'plot',
#    "zipf's",
#    'lawreading',
#    'formatted',
#    'data',
#    'rr:',
#    'remove',
#    'na',
#    'factor',
#    'vector',
#    'convert',
#    'numerichow',
#    'read',
#    'type',
#    'data',
#    'rusing',
#    'gsub',
#    'rredundant',
#    'facet',
#    'axis',
#    'labels',
#    'ggplot2error',
#    'fread',
#    '(showprogress',
#    'type',
#    'integer',
#    'type',
#    "'logical'.",
#    'please',
#    'report.)create',
#    'ts',
#    'object',
#    'daily',
#    'timeseriesgeom_tile',
#    'geom_text',
#    'facet_wrap',
#    'produce',
#    'incorrect',
#    'confusion',
#    'matriceshow',
#    'get',
#    'latex',
#    'table',
#    'latex()',
#    'hmisc',
#    'align',
#    'columnsmean',
#    'sd',
#    'tablelibtiff',
#    'install',
#    'macshiny:',
#    'display',
#    'progress',
#    'information',
#    'timeconsuming',
#    'function',
#    "running'x'",
#    "'y'",
#    'lengths',
#    'differ',
#    'fft',
#    'rttest',
#    'multiple',
#    'boxplots',
#    'rprincipal',
#    'component',
#    'analysis',
#    'elastic',
#    'net',
#    'regressionparallel',
#    'memory',
#    'duplication/usage',
#    'r?progress',
#    'bar',
#    'macparlapply',
#    'sqlquery',
#    'rodbcvector',
#    'subsetting',
#    'vs.',
#    'list',
#    'subsettinghow',
#    'could',
#    'know',
#    'columnname',
#    '/attribute',
#    'items',
#    'generated',
#    'rules%>%',
#    'operator',
#    'r',
#    'yields',
#    'unexpected',
#    'errorfigure',
#    'space',
#    'eps',
#    'plotsmatching',
#    'across',
#    'two',
#    'data',
#    'frames',
#    'certain',
#    'observations',
#    'multiple',
#    'entries',
#    'match',
#    'againsthow',
#    'extract',
#    'date',
#    'file',
#    'name',
#    'r?complement',
#    'genotype',
#    'conditionr',
#    'data',
#    'table',
#    'group',
#    'j',
#    'argumentr',
#    'igraph:',
#    'color',
#    'nodes',
#    'degree?when',
#    '[:punct:]',
#    'muchrselenium:',
#    'select',
#    'option',
#    'dropdownwhy',
#    'get',
#    'different',
#    'results',
#    'using',
#    'ccf()',
#    'cor()',
#    'r?how',
#    'know',
#    'significance',
#    'coefficients',
#    'model',
#    'weka?randomly',
#    'selecting',
#    'subset',
#    'rowsrunning',
#    'r',
#    'code',
#    'remotely',
#    'java',
#    'applicationr',
#    'pca',
#    'using',
#    '7',
#    'featuresdisplaying',
#    'pvalues',
#    'instead',
#    'ses',
#    'parenthesistrouble',
#    'plotting',
#    'predict',
#    'line',
#    'rhow',
#    'plot',
#    'greek',
#    'letters',
#    'evaluated',
#    'variables',
#    'together?creating',
#    'data.frame',
#    'new',
#    'row',
#    'iterationvariable',
#    'title',
#    'rmarkdownis',
#    'sequencematcher',
#    'r?how',
#    'would',
#    'vectorise',
#    'loop',
#    'r',
#    '(s',
#    '+=',
#    'i/2)?extracting',
#    'data',
#    'sets',
#    'unstructured',
#    'data',
#    'r/',
#    'pythonhow',
#    'pass',
#    'fun.aggregate',
#    'argument',
#    'dcast.data.table?interpretation',
#    'step',
#    'size',
#    'parameter',
#    'deoptim',
#    'packagesharing',
#    'data.table',
#    'memory',
#    'parallel',
#    'computinghow',
#    'dynamically',
#    'add',
#    'data',
#    'dataframe?arguments',
#    'descriptions',
#    'order',
#    '.rd',
#    'file',
#    'using',
#    'roxygen2',
#    'tag',
#    '@inheritparamschange',
#    'title',
#    "geom_histogram's",
#    'legendhow',
#    'detect',
#    'substrings',
#    'multiple',
#    'lists',
#    'within',
#    'string',
#    'restimating',
#    'r2',
#    'linear',
#    'regression',
#    'manually',
#    'changing',
#    'beta',
#    'coefficientanother',
#    'way',
#    'access',
#    'matrix',
#    'elements',
#    'rr',
#    'markdown',
#    'link',
#    'formatted',
#    'blue',
#    'knitted',
#    'pdferrors',
#    'running',
#    'shiny',
#    'application',
#    'server',
#    'debugerror',
#    'choosecranmirror()',
#    'r',
#    '3.2.2how',
#    'compute',
#    'effects',
#    'way',
#    "r's",
#    'lm.fit()?what',
#    'fastest',
#    'way',
#    'calculate',
#    'first',
#    'two',
#    'principal',
#    'components',
#    'r?natural',
#    'way',
#    'represent',
#    'hash',
#    'tables/dictionaries/maps',
#    'rbinding',
#    'several',
#    'large',
#    'matrices',
#    'columnmulti',
#    'variables',
#    'plotlsf',
#    'sequential',
#    'file',
#    'name',
#    'job',
#    'submissionr',
#    'ggplot',
#    'dropping',
#    'factorcreating',
#    'heatmap',
#    'based',
#    'historical',
#    'map',
#    'rchanging',
#    'hover',
#    'ggplotly',
#    'facet_gridas.date',
#    'keeps',
#    'returning',
#    'nasexporting',
#    'multiple',
#    'glm',
#    'plots',
#    'pngs?ggplot2:',
#    'add',
#    'additional',
#    'guide',
#    'diamond',
#    'shaped',
#    'ppintscoloring',
#    'certain',
#    'sections',
#    'barplot',
#    'based',
#    'position',
#    'matrixhow',
#    'render',
#    'html',
#    'plot',
#    'shiny',
#    'apphow',
#    'get',
#    'ouput',
#    'result',
#    'json',
#    'rassign',
#    'value',
#    'r',
#    'sparsematrixr',
#    'daily',
#    'data',
#    'time',
#    'series',
#    'year',
#    'weekunused',
#    'arguments',
#    'getportfolio',
#    'using',
#    'rsplitting',
#    'rules',
#    'mvpart',
#    'vs',
#    'rpartreturn',
#    'values',
#    'python',
#    'script',
#    'r',
#    'storing',
#    'values',
#    '`r`request',
#    'improve',
#    'code',
#    'download',
#    'sequence',
#    'urlswhat',
#    'parameters',
#    'mean',
#    'package',
#    'h5',
#    'rgetting',
#    'data',
#    'raster',
#    'file',
#    'rhow',
#    'generate',
#    'classification',
#    'analysis',
#    'tables',
#    'r?grouped',
#    'bargraph',
#    'r',
#    'problems',
#    'scale',
#    'error',
#    'barsr',
#    'building',
#    'json',
#    'file',
#    'appending',
#    'requestsremove',
#    'lines',
#    'efficient',
#    'waysmallest',
#    'size',
#    'ggplot2',
#    'geom_text()calculation',
#    'anomalies',
#    'timeserieshow',
#    'measure',
#    'graph',
#    'statistics',
#    'multiple',
#    'points',
#    'time',
#    '(slices)',
#    'using',
#    'networkdynamic',
#    'tsna?get',
#    'data',
#    'lines()',
#    'functionplyr',
#    'along',
#    'two',
#    'dimensions',
#    '(ddply)heatmap',
#    'generation',
#    'rassigning',
#    'numericvector',
#    'column',
#    'dataframeparallelism',
#    'julia.',
#    'features',
#    'limitationscentre',
#    'title',
#    'pdf',
#    'converted',
#    'markdown',
#    'using',
#    'pandochow',
#    'sliderinput',
#    'datesr',
#    'splitting',
#    'row',
#    'multiple',
#    'rowsr',
#    'forecasting',
#    'package',
#    'daily',
#    'timeseriessubset',
#    'dta.frame',
#    'according',
#    'repeated',
#    'colnamehow',
#    'manipulate',
#    'grids',
#    'axis',
#    "ggplot2?i'm",
#    'coding',
#    'r',
#    'trouble',
#    'statementsis',
#    'way',
#    'get',
#    'tapply',
#    'work',
#    'two',
#    'index',
#    'values',
#    '(or',
#    'equivilent)?r',
#    'oce',
#    'apply',
#    'read.topo',
#    'as.topo',
#    '.xyz',
#    'file',
#    'etopo1how',
#    'reclaim',
#    'memory',
#    'used',
#    'mgcv?store',
#    'output',
#    'text',
#    'r',
#    'shiny',
#    'object',
#    'outside',
#    'appindexing',
#    'neigboring',
#    'values',
#    'without',
#    'loopgather',
#    'multiple',
#    'date/value',
#    'columns',
#    'using',
#    'tidyrsubset',
#    'data',
#    'using',
#    'nonsequential',
#    'row',
#    'numbersexplain',
#    'quantile()',
#    'function',
#    'rchisquare',
#    'p',
#    'value',
#    'matrix',
#    'roptimizing',
#    'performance',
#    'forloops',
#    "rbenford's",
#    'law',
#    'rmanipulating',
#    'items',
#    'vector',
#    'r',
#    'without',
#    'using',
#    'loopsreading',
#    'messy',
#    'csv',
#    'using',
#    'readlines',
#    'certain',
#    'row',
#    '/',
#    'cell',
#    'valuemodify',
#    'limit',
#    'axis',
#    'plot.acf',
#    '(package',
#    'nlme)how',
#    'visualize',
#    'pairwise',
#    'comparisons',
#    '`ggplot2`?readpdf',
#    '(tm',
#    'package)',
#    'rexpand',
#    'vector',
#    'based',
#    'another',
#    'vectorinterpreting',
#    'interactions',
#    'regression',
#    'modelcustomize',
#    'xaxis',
#    'labels',
#    'dates',
#    'rgeom_segment',
#    'arrow',
#    'directionr',
#    'subsetting',
#    'list',
#    'objects',
#    'global',
#    'environment',
#    'classissues',
#    'simulating',
#    'seasonal',
#    'arima',
#    'modelwhy',
#    "doesn't",
#    'assign()',
#    'values',
#    'list',
#    'element',
#    'work',
#    'r?merging',
#    'rows',
#    'binary',
#    'data',
#    'based',
#    'columns',
#    'using',
#    'ddplycreating',
#    'objects',
#    'alphashape3d',
#    'rggplot2:',
#    'ignoring',
#    'nan',
#    'values',
#    'plotting',
#    'error',
#    'barsadding',
#    'overall',
#    'kaplan',
#    'meier',
#    'curve',
#    'using',
#    'autoplot',
#    'rr',
#    'error:',
#    'format=navisualizing',
#    'hierarchical',
#    'data',
#    'circle',
#    'packing',
#    'ggplot2?replacing',
#    'part',
#    'delimited',
#    'string',
#    "r's",
#    'regexhow',
#    'nona',
#    'used',
#    'rcpp?documenting',
#    'dataset',
#    'roxygen2do',
#    'r',
#    'ides',
#    'support',
#    'conditional',
#    'breakpoints?in',
#    'r:',
#    'reorder',
#    'rows',
#    'dataframe',
#    'based',
#    'another',
#    'tableedit',
#    'width',
#    'one',
#    'bar',
#    'ggplot',
#    'bargraph',
#    'fill',
#    'optionhow',
#    'calculate',
#    'average',
#    'certain',
#    'consecutive',
#    'data',
#    'values',
#    'rr:',
#    'utf8',
#    'character',
#    'bytes',
#    'latin1',
#    'characters',
#    'bytessubstring',
#    'like',
#    'matches',
#    'inside',
#    'regular',
#    'expressions?strange',
#    'interaction',
#    'r',
#    'package',
#    'xlconnect',
#    'choose.files()generate',
#    'timeseries',
#    'vector',
#    '(spatial',
#    'average)',
#    'netcdf',
#    'runiform',
#    'distribution',
#    'stan/r',
#    'causes',
#    'sampling',
#    'errorminimum',
#    'number',
#    'rows',
#    'data',
#    'set',
#    'accurate',
#    'predictionsread',
#    'file',
#    'many',
#    'lower',
#    'triangular',
#    'matrices',
#    'convert',
#    'pairwise',
#    'comparisonskorean',
#    'encoding',
#    'issues',
#    'rhow',
#    'get',
#    'number',
#    'returns',
#    'threshold',
#    'r?how',
#    'draw',
#    'regression',
#    'tree',
#    'correctly',
#    'clustering',
#    'using',
#    'ravoiding',
#    'simple',
#    'mapping',
#    'functiongsub',
#    'reduce',
#    'repeating',
#    'characters',
#    'one',
#    'instanceremove',
#    'quotes',
#    'paste()',
#    'output',
#    'r',
#    'preserving',
#    'classr',
#    'disabled',
#    'action',
#    'button',
#    'conditional',
#    "column's",
#    'nameassign',
#    'id',
#    'column',
#    'one',
#    'data',
#    'frame',
#    'another',
#    'using',
#    'values',
#    'multiple',
#    'columnsbarplot',
#    'r',
#    '3.1.1downloadhandler()',
#    'problems:',
#    'macos',
#    'fine',
#    'result',
#    'windowswrite',
#    'plot',
#    'text/binary',
#    'variableusing',
#    'seq()',
#    'subset',
#    'group',
#    '100',
#    'rows',
#    'every',
#    'nth',
#    'rowcounting',
#    'values',
#    'matrix',
#    'conditionallyincorrect',
#    'number',
#    'dimensions',
#    'r',
#    'create',
#    'subsetshiny:',
#    'get',
#    'underlying',
#    'reactive',
#    'value',
#    'server',
#    'sider:',
#    'rvest',
#    'package',
#    'read_html()',
#    'function',
#    'gives',
#    'different',
#    'outputs',
#    'urlancova',
#    'wrs2',
#    'r:',
#    'producing',
#    'row.names',
#    'error?code',
#    'chunk',
#    'font',
#    'size',
#    'rmarkdown',
#    'knitr',
#    'latexintersect',
#    'graphs',
#    'sharing',
#    'percentage',
#    'edges',
#    'verticeshow',
#    'know',
#    'functions',
#    'r',
#    'flagged',
#    'debugging?cluster',
#    'sequences',
#    'strings',
#    'ruser',
#    'defined',
#    'function',
#    'input',
#    'loop',
#    'every',
#    'row',
#    'data',
#    'framehow',
#    'create',
#    'interactive',
#    'waterfall',
#    'plot?',
#    'rcreate',
#    'stacked',
#    'barplot',
#    'stack',
#    'scaled',
#    'sum',
#    '100%readhtmltable',
#    'r',
#    'throws',
#    'warning',
#    'within',
#    'loopr',
#    'color',
#    'palettes',
#    'many',
#    'data',
#    'classesr',
#    'update',
#    'selection',
#    'boxes',
#    'shinyplot',
#    'different',
#    'reactive',
#    'graph',
#    'using',
#    'different',
#    'dataset',
#    'columns',
#    'based',
#    'reacitve',
#    'inputs',
#    'shinyin',
#    'r',
#    ':',
#    'extract',
#    'information',
#    'text',
#    'sentencewebscraping',
#    'using',
#    'httr:get',
#    'function',
#    'gives',
#    "'status:",
#    "503'difference",
#    'md5',
#    'hash',
#    'rlibrarys',
#    'md5',
#    'serialized',
#    'objects"""roc""',
#    'metric',
#    'result',
#    'set"r',
#    'aggregate',
#    'max',
#    'parameter',
#    'based',
#    'multiple',
#    'columnshow',
#    '[[',
#    ']]',
#    'work',
#    'loop',
#    'r?glmm',
#    'random',
#    'vs',
#    'fixed',
#    'terms',
#    'rr:',
#    'strange',
#    'unwanted',
#    'output',
#    'readlinehow',
#    'identify',
#    'indexes',
#    'elements',
#    'appearing',
#    'vector',
#    'r?r',
#    'using',
#    'fread',
#    'colclasses',
#    'skip',
#    'arguments',
#    'read',
#    'csv',
#    'column',
#    'headersfilter',
#    'multiple',
#    'conditions',
#    'dplyrbuilding',
#    'r',
#    'packages',
#    'using',
#    'alternate',
#    'gccincluding',
#    'missing',
#    'values',
#    'table()',
#    'results',
#    ...]),
#  ('bigdata',
#   ['r',
#    'custom',
#    'parser',
#    'functionreturning',
#    'lots',
#    'items',
#    'mongodb',
#    'via',
#    'node.jsspark',
#    'shell',
#    'unable',
#    'read',
#    'file',
#    'valid',
#    'pathbinding',
#    'several',
#    'large',
#    'matrices',
#    'columnanalyzing',
#    '115000',
#    'strings',
#    'pasted',
#    'consolecount',
#    'number',
#    'records',
#    'column',
#    'family',
#    'hbase',
#    'tableusing',
#    'elasticsearch',
#    'hadoop',
#    'map',
#    'reduceerror',
#    'make',
#    'apps',
#    'huecode',
#    'algo',
#    'modulo',
#    'divisionhow',
#    'reexecution',
#    'would',
#    'primary',
#    'source',
#    'fault',
#    'tolerance?'])]

# %%
# step6: counting the word using Counter package
step6 = step5.flatMap(lambda z: [z[0], Counter(z[1]).most_common(5)])
step6.take(40)
# Out:
# ['php',
#  [('php', 496), ('using', 244), ('mysql', 159), ('array', 155), ('file', 136)],
#  'svn',
#  [('svn', 41),
#   ('subversion', 12),
#   ('repository', 10),
#   ('files', 7),
#   ('version', 6)],
#  'tortoisesvn',
#  [('svn', 5),
#   ('tortoisesvn', 5),
#   ('windows', 3),
#   ('specific', 2),
#   ('folder', 2)],
#  'r',
#  [('r', 65), ('data', 55), ('using', 41), ('values', 35), ('multiple', 27)],
#  'bigdata',
#  [('r', 1),
#   ('custom', 1),
#   ('parser', 1),
#   ('functionreturning', 1),
#   ('lots', 1)],
#  'customization',
#  [('custom', 7), ('add', 2), ('create', 2), ('cell', 1), ('action', 1)],
#  'contacts',
#  [('contacts', 3), ('add', 2), ('custom', 2), ('android', 2), ('cell', 1)],
#  'parse.com',
#  [('parse', 14), ('data', 8), ('using', 7), ('swift', 6), ('push', 5)],
#  'push',
#  [('push', 11), ('send', 3), ('notification', 3), ('git', 3), ('data', 2)],
#  'html',
#  [('html', 242), ('using', 136), ('div', 131), ('text', 93), ('page', 90)],
#  'google-chrome',
#  [('chrome', 52), ('google', 12), ('using', 9), ('working', 9), ('get', 6)],
#  'python',
#  [('python', 344),
#   ('using', 183),
#   ('list', 119),
#   ('file', 97),
#   ('string', 83)],
#  'matlab',
#  [('matlab', 37),
#   ('using', 19),
#   ('matrix', 15),
#   ('function', 13),
#   ('data', 12)],
#  'numpy',
#  [('numpy', 33), ('array', 21), ('arrays', 10), ('using', 10), ('python', 9)],
#  'machine-learning',
#  [('neural', 7), ('2', 4), ('data', 4), ('network', 4), ('size', 3)],
#  'mathematical-optimization',
#  [('lasso', 1),
#   ('regression', 1),
#   ('result', 1),
#   ('different', 1),
#   ('matlab', 1)],
#  'ruby',
#  [('ruby', 99), ('rails', 60), ('using', 44), ('method', 30), ('array', 29)],
#  'java',
#  [('java', 407),
#   ('using', 259),
#   ('file', 148),
#   ('method', 119),
#   ('class', 108)],
#  'static-analysis',
#  [('code', 3), ('static', 2), ('value', 2), ('java:', 1), ('ways', 1)],
#  'for-loop',
#  [('loop', 37), ('using', 7), ('multiple', 7), ('array', 6), ('variable', 6)]]

# %% [markdown]
# **Conclusion:**
#
# The final result contains the list of tags and their associated common words used in the titles. As expected, the most common word for each tag often is the name of the tag itself. This suggest that user often include the tag word in the title for better clarity. It's interesting to see some title words correlate closely with their tag such as "php" and "mysql" or "numpy" and "python".
#
# Due to the nature of these related words, perhaps they could be used to enhance the suggestion engine of the website, such as common topic raised by a specific community.
